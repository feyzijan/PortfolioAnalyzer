# %%
import pandas as pd
import requests

# %%
CMC_PRO_API_KEY= "31d0c093-d32a-4d4f-9ea4-b7f894edc76b"

# %%
coin_names = pd.read_csv("coinnames.csv")

# %%
coin_names.head(10)
# Out:
#   Symbol
# 0    BTC
# 1    ETH
# 2    BCH
# 3    XRP
# 4   DASH
# 5    LTC
# 6    ETC
# 7    ADA
# 8  MIOTA
# 9    XLM

# %% [markdown]
# ### CoinMarketCap API Implementation

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

def cmc_api(url, parameters):
    headers = {
      'Accepts': 'application/json',
      'Accept-Encoding': 'deflate, gzip',
      'X-CMC_PRO_API_KEY': f'{CMC_PRO_API_KEY}',
    }

    session = Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
        return data
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)

# %% [markdown]
# Example Parameter and url to pass

# %%
url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/quotes/latest"
parameters = {
  'id':'1',
  'convert':'USD',
  'aux': 'num_market_pairs,cmc_rank,tags,platform,max_supply,circulating_supply,total_supply,market_cap_by_total_supply'
}

# %% [markdown]
# Map_data includes CMC IDs, symbols, and names for all cryptocurrencies

# %%
map_data
# Out:
# {'status': {'timestamp': '2021-11-07T00:49:43.918Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 26,
#   'credit_count': 1,
#   'notice': None},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'rank': 1,
#    'is_active': 1,
#    'first_historical_data': '2013-04-28T18:47:21.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'rank': 17,
#    'is_active': 1,
#    'first_historical_data': '2013-04-28T18:47:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 3,
#    'name': 'Namecoin',
#    'symbol': 'NMC',
#    'slug': 'namecoin',
#    'rank': 775,
#    'is_active': 1,
#    'first_historical_data': '2013-04-28T18:47:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 4,
#    'name': 'Terracoin',
#    'symbol': 'TRC',
#    'slug': 'terracoin',
#    'rank': 2026,
#    'is_active': 1,
#    'first_historical_data': '2013-04-28T18:47:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 5,
#    'name': 'Peercoin',
#    'symbol': 'PPC',
#    'slug': 'peercoin',
#    'rank': 835,
#    'is_active': 1,
#    'first_historical_data': '2013-04-28T18:47:23.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 6,
#    'name': 'Novacoin',
#    'symbol': 'NVC',
#    'slug': 'novacoin',
#    'rank': 1968,
#    'is_active': 1,
#    'first_historical_data': '2013-04-28T18:47:23.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 8,
#    'name': 'Feathercoin',
#    'symbol': 'FTC',
#    'slug': 'feathercoin',
#    'rank': 1325,
#    'is_active': 1,
#    'first_historical_data': '2013-05-03T03:25:15.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 10,
#    'name': 'Freicoin',
#    'symbol': 'FRC',
#    'slug': 'freicoin',
#    'rank': 2064,
#    'is_active': 1,
#    'first_historical_data': '2013-05-03T03:25:15.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 13,
#    'name': 'Ixcoin',
#    'symbol': 'IXC',
#    'slug': 'ixcoin',
#    'rank': 1505,
#    'is_active': 1,
#    'first_historical_data': '2013-05-08T05:20:18.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 16,
#    'name': 'WorldCoin',
#    'symbol': 'WDC',
#    'slug': 'worldcoin',
#    'rank': 5370,
#    'is_active': 1,
#    'first_historical_data': '2013-05-22T03:20:20.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 18,
#    'name': 'Digitalcoin',
#    'symbol': 'DGC',
#    'slug': 'digitalcoin',
#    'rank': 2158,
#    'is_active': 1,
#    'first_historical_data': '2013-06-09T17:55:21.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 25,
#    'name': 'Goldcoin',
#    'symbol': 'GLC',
#    'slug': 'goldcoin',
#    'rank': 1353,
#    'is_active': 1,
#    'first_historical_data': '2013-06-14T06:45:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 35,
#    'name': 'Phoenixcoin',
#    'symbol': 'PXC',
#    'slug': 'phoenixcoin',
#    'rank': 1688,
#    'is_active': 1,
#    'first_historical_data': '2013-07-04T05:15:49.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 37,
#    'name': 'Megacoin',
#    'symbol': 'MEC',
#    'slug': 'megacoin',
#    'rank': 2248,
#    'is_active': 1,
#    'first_historical_data': '2013-07-07T13:56:51.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 41,
#    'name': 'Infinitecoin',
#    'symbol': 'IFC',
#    'slug': 'infinitecoin',
#    'rank': 864,
#    'is_active': 1,
#    'first_historical_data': '2013-07-10T13:27:02.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 42,
#    'name': 'Primecoin',
#    'symbol': 'XPM',
#    'slug': 'primecoin',
#    'rank': 1362,
#    'is_active': 1,
#    'first_historical_data': '2013-07-11T03:21:19.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 43,
#    'name': 'Anoncoin',
#    'symbol': 'ANC',
#    'slug': 'anoncoin',
#    'rank': 2349,
#    'is_active': 1,
#    'first_historical_data': '2013-07-15T01:31:35.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 45,
#    'name': 'CasinoCoin',
#    'symbol': 'CSC',
#    'slug': 'casinocoin',
#    'rank': 3415,
#    'is_active': 1,
#    'first_historical_data': '2013-07-25T03:06:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 50,
#    'name': 'Emerald Crypto',
#    'symbol': 'EMD',
#    'slug': 'emerald',
#    'rank': 2275,
#    'is_active': 1,
#    'first_historical_data': '2013-08-04T18:51:31.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'rank': 7,
#    'is_active': 1,
#    'first_historical_data': '2013-08-04T18:51:05.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 53,
#    'name': 'Quark',
#    'symbol': 'QRK',
#    'slug': 'quark',
#    'rank': 1095,
#    'is_active': 1,
#    'first_historical_data': '2013-08-25T17:46:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 56,
#    'name': 'Zetacoin',
#    'symbol': 'ZET',
#    'slug': 'zetacoin',
#    'rank': 2183,
#    'is_active': 1,
#    'first_historical_data': '2013-09-11T01:47:21.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 61,
#    'name': 'TagCoin',
#    'symbol': 'TAG',
#    'slug': 'tagcoin',
#    'rank': 2113,
#    'is_active': 1,
#    'first_historical_data': '2013-11-05T13:32:08.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 64,
#    'name': 'Public Index Network',
#    'symbol': 'PIN',
#    'slug': 'public-index-network',
#    'rank': 1304,
#    'is_active': 1,
#    'first_historical_data': '2013-11-27T06:01:46.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 66,
#    'name': 'Nxt',
#    'symbol': 'NXT',
#    'slug': 'nxt',
#    'rank': 911,
#    'is_active': 1,
#    'first_historical_data': '2013-12-04T05:46:40.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 67,
#    'name': 'Unobtanium',
#    'symbol': 'UNO',
#    'slug': 'unobtanium',
#    'rank': 5699,
#    'is_active': 1,
#    'first_historical_data': '2013-12-21T18:17:35.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 69,
#    'name': 'Datacoin',
#    'symbol': 'DTC',
#    'slug': 'datacoin',
#    'rank': 2584,
#    'is_active': 1,
#    'first_historical_data': '2013-12-07T19:47:06.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 72,
#    'name': 'Deutsche eMark',
#    'symbol': 'DEM',
#    'slug': 'deutsche-emark',
#    'rank': 2390,
#    'is_active': 1,
#    'first_historical_data': '2013-12-15T01:52:15.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'rank': 9,
#    'is_active': 1,
#    'first_historical_data': '2013-12-15T14:42:34.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 77,
#    'name': 'Diamond',
#    'symbol': 'DMD',
#    'slug': 'diamond',
#    'rank': 1058,
#    'is_active': 1,
#    'first_historical_data': '2013-12-19T12:31:59.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 78,
#    'name': 'HoboNickels',
#    'symbol': 'HBN',
#    'slug': 'hobonickels',
#    'rank': 6146,
#    'is_active': 1,
#    'first_historical_data': '2013-12-20T13:32:39.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 80,
#    'name': 'Orbitcoin',
#    'symbol': 'ORB',
#    'slug': 'orbitcoin',
#    'rank': 1852,
#    'is_active': 1,
#    'first_historical_data': '2013-12-21T18:12:54.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 83,
#    'name': 'Omni',
#    'symbol': 'OMNI',
#    'slug': 'omni',
#    'rank': 1651,
#    'is_active': 1,
#    'first_historical_data': '2013-12-24T23:37:41.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 87,
#    'name': 'FedoraCoin',
#    'symbol': 'TIPS',
#    'slug': 'fedoracoin',
#    'rank': 1494,
#    'is_active': 1,
#    'first_historical_data': '2013-12-31T16:17:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 90,
#    'name': 'Dimecoin',
#    'symbol': 'DIME',
#    'slug': 'dimecoin',
#    'rank': 1634,
#    'is_active': 1,
#    'first_historical_data': '2014-01-06T07:42:29.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 93,
#    'name': '42-coin',
#    'symbol': '42',
#    'slug': '42-coin',
#    'rank': 1346,
#    'is_active': 1,
#    'first_historical_data': '2014-01-14T04:32:01.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 99,
#    'name': 'Vertcoin',
#    'symbol': 'VTC',
#    'slug': 'vertcoin',
#    'rank': 669,
#    'is_active': 1,
#    'first_historical_data': '2014-01-20T05:27:57.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 109,
#    'name': 'DigiByte',
#    'symbol': 'DGB',
#    'slug': 'digibyte',
#    'rank': 126,
#    'is_active': 1,
#    'first_historical_data': '2014-02-06T13:13:38.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 113,
#    'name': 'SmartCoin (SMC)',
#    'symbol': 'SMC',
#    'slug': 'smartcoin',
#    'rank': 2103,
#    'is_active': 1,
#    'first_historical_data': '2014-02-06T13:13:41.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 118,
#    'name': 'ReddCoin',
#    'symbol': 'RDD',
#    'slug': 'redd',
#    'rank': 480,
#    'is_active': 1,
#    'first_historical_data': '2014-02-10T00:58:17.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 122,
#    'name': 'PotCoin',
#    'symbol': 'POT',
#    'slug': 'potcoin',
#    'rank': 1450,
#    'is_active': 1,
#    'first_historical_data': '2014-02-10T04:23:33.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 125,
#    'name': 'Blakecoin',
#    'symbol': 'BLC',
#    'slug': 'blakecoin',
#    'rank': 2619,
#    'is_active': 1,
#    'first_historical_data': '2014-02-12T06:50:14.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 128,
#    'name': 'Maxcoin',
#    'symbol': 'MAX',
#    'slug': 'maxcoin',
#    'rank': 1963,
#    'is_active': 1,
#    'first_historical_data': '2014-02-12T13:33:59.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 131,
#    'name': 'Dash',
#    'symbol': 'DASH',
#    'slug': 'dash',
#    'rank': 75,
#    'is_active': 1,
#    'first_historical_data': '2014-02-14T13:44:09.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 132,
#    'name': 'Counterparty',
#    'symbol': 'XCP',
#    'slug': 'counterparty',
#    'rank': 641,
#    'is_active': 1,
#    'first_historical_data': '2014-02-15T13:59:36.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 141,
#    'name': 'MintCoin',
#    'symbol': 'MINT',
#    'slug': 'mintcoin',
#    'rank': 6081,
#    'is_active': 1,
#    'first_historical_data': '2014-02-19T13:39:53.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 145,
#    'name': 'DopeCoin',
#    'symbol': 'DOPE',
#    'slug': 'dopecoin',
#    'rank': 2102,
#    'is_active': 1,
#    'first_historical_data': '2014-02-22T17:52:34.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 148,
#    'name': 'Auroracoin',
#    'symbol': 'AUR',
#    'slug': 'auroracoin',
#    'rank': 5832,
#    'is_active': 1,
#    'first_historical_data': '2014-02-27T05:33:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 151,
#    'name': 'Peseta Digital',
#    'symbol': 'PTD',
#    'slug': 'pesetacoin',
#    'rank': 2539,
#    'is_active': 1,
#    'first_historical_data': '2014-02-22T17:52:40.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 154,
#    'name': 'Marscoin',
#    'symbol': 'MARS',
#    'slug': 'marscoin',
#    'rank': 4552,
#    'is_active': 1,
#    'first_historical_data': '2014-02-24T13:41:14.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 162,
#    'name': 'Magic Internet Money',
#    'symbol': 'MIM',
#    'slug': 'magic-internet-money',
#    'rank': 2721,
#    'is_active': 1,
#    'first_historical_data': '2014-03-12T05:27:57.000Z',
#    'last_historical_data': '2021-11-07T00:40:04.000Z',
#    'platform': None},
#   {'id': 168,
#    'name': 'Uniform Fiscal Object',
#    'symbol': 'UFO',
#    'slug': 'uniform-fiscal-object',
#    'rank': 5652,
#    'is_active': 1,
#    'first_historical_data': '2014-02-27T05:33:35.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 170,
#    'name': 'BlackCoin',
#    'symbol': 'BLK',
#    'slug': 'blackcoin',
#    'rank': 1461,
#    'is_active': 1,
#    'first_historical_data': '2014-02-28T05:13:44.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 175,
#    'name': 'Photon',
#    'symbol': 'PHO',
#    'slug': 'photon',
#    'rank': 2242,
#    'is_active': 1,
#    'first_historical_data': '2014-05-23T11:20:40.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 182,
#    'name': 'Myriad',
#    'symbol': 'XMY',
#    'slug': 'myriad',
#    'rank': 1293,
#    'is_active': 1,
#    'first_historical_data': '2014-03-08T15:56:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 184,
#    'name': 'DNotes',
#    'symbol': 'NOTE',
#    'slug': 'dnotes',
#    'rank': 2491,
#    'is_active': 1,
#    'first_historical_data': '2014-03-08T15:56:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 201,
#    'name': 'Einsteinium',
#    'symbol': 'EMC2',
#    'slug': 'einsteinium',
#    'rank': 1098,
#    'is_active': 1,
#    'first_historical_data': '2014-04-09T04:10:24.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 212,
#    'name': 'ECC',
#    'symbol': 'ECC',
#    'slug': 'eccoin',
#    'rank': 6073,
#    'is_active': 1,
#    'first_historical_data': '2014-03-20T05:09:55.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 213,
#    'name': 'MonaCoin',
#    'symbol': 'MONA',
#    'slug': 'monacoin',
#    'rank': 458,
#    'is_active': 1,
#    'first_historical_data': '2014-03-20T05:09:55.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 215,
#    'name': 'Rubycoin',
#    'symbol': 'RBY',
#    'slug': 'rubycoin',
#    'rank': 6320,
#    'is_active': 1,
#    'first_historical_data': '2014-03-20T05:09:56.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 217,
#    'name': 'Bela',
#    'symbol': 'BELA',
#    'slug': 'belacoin',
#    'rank': 2223,
#    'is_active': 1,
#    'first_historical_data': '2014-03-20T05:10:07.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2e98a6804e4b6c832ed0ca876a943abd3400b224'}},
#   {'id': 224,
#    'name': 'FairCoin',
#    'symbol': 'FAIR',
#    'slug': 'faircoin',
#    'rank': 1676,
#    'is_active': 1,
#    'first_historical_data': '2014-03-22T14:59:12.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 234,
#    'name': 'e-Gulden',
#    'symbol': 'EFL',
#    'slug': 'e-gulden',
#    'rank': 1537,
#    'is_active': 1,
#    'first_historical_data': '2014-03-26T12:44:50.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 254,
#    'name': 'Gulden',
#    'symbol': 'NLG',
#    'slug': 'gulden',
#    'rank': 1195,
#    'is_active': 1,
#    'first_historical_data': '2014-04-08T04:11:00.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 258,
#    'name': 'Groestlcoin',
#    'symbol': 'GRS',
#    'slug': 'groestlcoin',
#    'rank': 504,
#    'is_active': 1,
#    'first_historical_data': '2014-04-11T20:45:53.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 260,
#    'name': 'PetroDollar',
#    'symbol': 'XPD',
#    'slug': 'petrodollar',
#    'rank': 1897,
#    'is_active': 1,
#    'first_historical_data': '2014-04-15T04:36:55.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 263,
#    'name': 'PLNcoin',
#    'symbol': 'PLNC',
#    'slug': 'plncoin',
#    'rank': 2652,
#    'is_active': 1,
#    'first_historical_data': '2014-04-15T04:36:58.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 268,
#    'name': 'WhiteCoin',
#    'symbol': 'XWC',
#    'slug': 'whitecoin',
#    'rank': 228,
#    'is_active': 1,
#    'first_historical_data': '2014-04-18T12:12:07.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 276,
#    'name': 'Bitstar',
#    'symbol': 'BITS',
#    'slug': 'bitstar',
#    'rank': 2078,
#    'is_active': 1,
#    'first_historical_data': '2014-04-23T12:01:13.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 278,
#    'name': 'Quebecoin',
#    'symbol': 'QBC',
#    'slug': 'quebecoin',
#    'rank': 2604,
#    'is_active': 1,
#    'first_historical_data': '2014-04-23T12:01:15.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 290,
#    'name': 'BlueCoin',
#    'symbol': 'BLU',
#    'slug': 'bluecoin',
#    'rank': 2155,
#    'is_active': 1,
#    'first_historical_data': '2014-04-28T03:21:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 291,
#    'name': 'MaidSafeCoin',
#    'symbol': 'MAID',
#    'slug': 'maidsafecoin',
#    'rank': 295,
#    'is_active': 1,
#    'first_historical_data': '2014-04-28T03:21:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 293,
#    'name': 'Bitcoin Plus',
#    'symbol': 'XBC',
#    'slug': 'bitcoin-plus',
#    'rank': 1642,
#    'is_active': 1,
#    'first_historical_data': '2014-05-04T01:31:45.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 298,
#    'name': 'NewYorkCoin',
#    'symbol': 'NYC',
#    'slug': 'newyorkcoin',
#    'rank': 5767,
#    'is_active': 1,
#    'first_historical_data': '2014-05-06T12:17:49.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 313,
#    'name': 'Pinkcoin',
#    'symbol': 'PINK',
#    'slug': 'pinkcoin',
#    'rank': 1487,
#    'is_active': 1,
#    'first_historical_data': '2014-05-11T17:08:10.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 316,
#    'name': 'Dreamcoin',
#    'symbol': 'DRM',
#    'slug': 'dreamcoin',
#    'rank': 2449,
#    'is_active': 1,
#    'first_historical_data': '2014-05-13T04:03:16.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 322,
#    'name': 'Energycoin',
#    'symbol': 'ENRG',
#    'slug': 'energycoin',
#    'rank': 2439,
#    'is_active': 1,
#    'first_historical_data': '2014-05-15T12:42:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 323,
#    'name': 'VeriCoin',
#    'symbol': 'VRC',
#    'slug': 'vericoin',
#    'rank': 1663,
#    'is_active': 1,
#    'first_historical_data': '2014-05-16T12:13:34.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 328,
#    'name': 'Monero',
#    'symbol': 'XMR',
#    'slug': 'monero',
#    'rank': 42,
#    'is_active': 1,
#    'first_historical_data': '2014-05-21T01:41:13.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 331,
#    'name': 'Litecoin Plus',
#    'symbol': 'LCP',
#    'slug': 'litecoin-plus',
#    'rank': 2358,
#    'is_active': 1,
#    'first_historical_data': '2014-05-21T03:17:29.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 333,
#    'name': 'Curecoin',
#    'symbol': 'CURE',
#    'slug': 'curecoin',
#    'rank': 1544,
#    'is_active': 1,
#    'first_historical_data': '2014-05-26T18:12:11.000Z',
#    'last_historical_data': '2021-11-07T00:39:04.000Z',
#    'platform': None},
#   {'id': 341,
#    'name': 'SuperCoin',
#    'symbol': 'SUPER',
#    'slug': 'supercoin',
#    'rank': 2309,
#    'is_active': 1,
#    'first_historical_data': '2014-05-26T16:31:29.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 360,
#    'name': 'Motocoin',
#    'symbol': 'MOTO',
#    'slug': 'motocoin',
#    'rank': 1749,
#    'is_active': 1,
#    'first_historical_data': '2014-06-03T12:47:54.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 362,
#    'name': 'CloakCoin',
#    'symbol': 'CLOAK',
#    'slug': 'cloakcoin',
#    'rank': 1511,
#    'is_active': 1,
#    'first_historical_data': '2014-06-07T00:08:01.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 366,
#    'name': 'BitSend',
#    'symbol': 'BSD',
#    'slug': 'bitsend',
#    'rank': 2427,
#    'is_active': 1,
#    'first_historical_data': '2014-06-08T14:20:12.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 367,
#    'name': 'Coin2.1',
#    'symbol': 'C2',
#    'slug': 'coin2-1',
#    'rank': 2398,
#    'is_active': 1,
#    'first_historical_data': '2014-06-08T14:20:12.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 372,
#    'name': 'Bytecoin',
#    'symbol': 'BCN',
#    'slug': 'bytecoin-bcn',
#    'rank': 525,
#    'is_active': 1,
#    'first_historical_data': '2014-06-17T13:01:53.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 377,
#    'name': 'Navcoin',
#    'symbol': 'NAV',
#    'slug': 'nav-coin',
#    'rank': 784,
#    'is_active': 1,
#    'first_historical_data': '2014-06-12T11:43:36.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 389,
#    'name': 'Startcoin',
#    'symbol': 'START',
#    'slug': 'startcoin',
#    'rank': 2282,
#    'is_active': 1,
#    'first_historical_data': '2014-06-15T14:58:33.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 405,
#    'name': 'DigitalNote',
#    'symbol': 'XDN',
#    'slug': 'digitalnote',
#    'rank': 1162,
#    'is_active': 1,
#    'first_historical_data': '2014-06-24T12:58:43.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 406,
#    'name': 'Boolberry',
#    'symbol': 'BBR',
#    'slug': 'boolberry',
#    'rank': 2626,
#    'is_active': 1,
#    'first_historical_data': '2014-06-24T12:58:43.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 416,
#    'name': 'HempCoin',
#    'symbol': 'THC',
#    'slug': 'hempcoin',
#    'rank': 1444,
#    'is_active': 1,
#    'first_historical_data': '2014-06-28T16:33:33.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 448,
#    'name': 'Stealth',
#    'symbol': 'XST',
#    'slug': 'stealth',
#    'rank': 1593,
#    'is_active': 1,
#    'first_historical_data': '2014-07-10T12:16:32.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 460,
#    'name': 'Clams',
#    'symbol': 'CLAM',
#    'slug': 'clams',
#    'rank': 6324,
#    'is_active': 1,
#    'first_historical_data': '2014-08-26T02:34:53.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 463,
#    'name': 'BitShares',
#    'symbol': 'BTS',
#    'slug': 'bitshares',
#    'rank': 376,
#    'is_active': 1,
#    'first_historical_data': '2014-07-21T03:44:18.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 470,
#    'name': 'Viacoin',
#    'symbol': 'VIA',
#    'slug': 'viacoin',
#    'rank': 1330,
#    'is_active': 1,
#    'first_historical_data': '2014-07-18T12:24:19.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 495,
#    'name': 'I/O Coin',
#    'symbol': 'IOC',
#    'slug': 'iocoin',
#    'rank': 1599,
#    'is_active': 1,
#    'first_historical_data': '2014-08-02T18:34:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:05.000Z',
#    'platform': None},
#   {'id': 501,
#    'name': 'Cryptonite',
#    'symbol': 'XCN',
#    'slug': 'cryptonite',
#    'rank': 2097,
#    'is_active': 1,
#    'first_historical_data': '2014-08-02T21:19:20.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 502,
#    'name': 'Carboncoin',
#    'symbol': 'CARBON',
#    'slug': 'carboncoin',
#    'rank': 1145,
#    'is_active': 1,
#    'first_historical_data': '2014-08-02T21:19:20.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 506,
#    'name': 'CannabisCoin',
#    'symbol': 'CANN',
#    'slug': 'cannabiscoin',
#    'rank': 1817,
#    'is_active': 1,
#    'first_historical_data': '2014-08-02T22:04:20.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'rank': 25,
#    'is_active': 1,
#    'first_historical_data': '2014-08-05T05:44:19.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 541,
#    'name': 'Syscoin',
#    'symbol': 'SYS',
#    'slug': 'syscoin',
#    'rank': 296,
#    'is_active': 1,
#    'first_historical_data': '2014-08-20T11:04:21.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 551,
#    'name': 'Donu',
#    'symbol': 'DONU',
#    'slug': 'donu',
#    'rank': 2447,
#    'is_active': 1,
#    'first_historical_data': '2014-08-26T02:34:57.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 558,
#    'name': 'Emercoin',
#    'symbol': 'EMC',
#    'slug': 'emercoin',
#    'rank': 1513,
#    'is_active': 1,
#    'first_historical_data': '2014-08-23T21:24:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 572,
#    'name': 'RabbitCoin',
#    'symbol': 'RBBT',
#    'slug': 'rabbitcoin',
#    'rank': 6325,
#    'is_active': 1,
#    'first_historical_data': '2014-08-30T22:24:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 576,
#    'name': 'GameCredits',
#    'symbol': 'GAME',
#    'slug': 'gamecredits',
#    'rank': 678,
#    'is_active': 1,
#    'first_historical_data': '2014-09-01T16:54:21.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x63f88a2298a5c4aee3c216aa6d926b184a4b2437'}},
#   {'id': 584,
#    'name': 'NativeCoin',
#    'symbol': 'N8V',
#    'slug': 'native-coin',
#    'rank': 1863,
#    'is_active': 1,
#    'first_historical_data': '2014-09-06T15:54:23.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 588,
#    'name': 'Ubiq',
#    'symbol': 'UBQ',
#    'slug': 'ubiq',
#    'rank': 1186,
#    'is_active': 1,
#    'first_historical_data': '2014-09-07T21:39:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 597,
#    'name': 'Opal',
#    'symbol': 'OPAL',
#    'slug': 'opal',
#    'rank': 2176,
#    'is_active': 1,
#    'first_historical_data': '2014-09-13T17:14:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 601,
#    'name': 'Acoin',
#    'symbol': 'ACOIN',
#    'slug': 'acoin',
#    'rank': 2577,
#    'is_active': 1,
#    'first_historical_data': '2014-09-13T19:44:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 624,
#    'name': 'bitCNY',
#    'symbol': 'BITCNY',
#    'slug': 'bitcny',
#    'rank': 1371,
#    'is_active': 1,
#    'first_historical_data': '2014-09-23T04:24:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 626,
#    'name': 'NuBits',
#    'symbol': 'USNBT',
#    'slug': 'nubits',
#    'rank': 1627,
#    'is_active': 1,
#    'first_historical_data': '2014-09-24T01:34:23.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 633,
#    'name': 'ExclusiveCoin',
#    'symbol': 'EXCL',
#    'slug': 'exclusivecoin',
#    'rank': 2005,
#    'is_active': 1,
#    'first_historical_data': '2014-09-30T07:54:21.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 638,
#    'name': 'Trollcoin',
#    'symbol': 'TROLL',
#    'slug': 'trollcoin',
#    'rank': 1965,
#    'is_active': 1,
#    'first_historical_data': '2014-09-30T07:54:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 644,
#    'name': 'GlobalBoost-Y',
#    'symbol': 'BSTY',
#    'slug': 'globalboost-y',
#    'rank': 1913,
#    'is_active': 1,
#    'first_historical_data': '2014-10-03T12:39:24.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 656,
#    'name': 'Prime-XI',
#    'symbol': 'PXI',
#    'slug': 'prime-xi',
#    'rank': 2574,
#    'is_active': 1,
#    'first_historical_data': '2014-10-04T20:54:34.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 659,
#    'name': 'Bitswift',
#    'symbol': 'BITS',
#    'slug': 'bitswift',
#    'rank': 1841,
#    'is_active': 1,
#    'first_historical_data': '2014-10-05T17:44:24.000Z',
#    'last_historical_data': '2021-11-07T00:39:06.000Z',
#    'platform': None},
#   {'id': 693,
#    'name': 'Verge',
#    'symbol': 'XVG',
#    'slug': 'verge',
#    'rank': 163,
#    'is_active': 1,
#    'first_historical_data': '2014-10-25T22:14:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 699,
#    'name': 'NuShares',
#    'symbol': 'NSR',
#    'slug': 'nushares',
#    'rank': 2002,
#    'is_active': 1,
#    'first_historical_data': '2014-10-25T23:14:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 702,
#    'name': 'SpreadCoin',
#    'symbol': 'SPR',
#    'slug': 'spreadcoin',
#    'rank': 2572,
#    'is_active': 1,
#    'first_historical_data': '2014-10-26T23:24:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 703,
#    'name': 'Rimbit',
#    'symbol': 'RBT',
#    'slug': 'rimbit',
#    'rank': 2357,
#    'is_active': 1,
#    'first_historical_data': '2014-10-26T23:24:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 706,
#    'name': 'MonetaryUnit',
#    'symbol': 'MUE',
#    'slug': 'monetaryunit',
#    'rank': 1712,
#    'is_active': 1,
#    'first_historical_data': '2014-11-01T20:59:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 707,
#    'name': 'Blocknet',
#    'symbol': 'BLOCK',
#    'slug': 'blocknet',
#    'rank': 1107,
#    'is_active': 1,
#    'first_historical_data': '2014-11-01T21:19:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 719,
#    'name': 'Limitless VIP',
#    'symbol': 'VIP',
#    'slug': 'limitless-vip',
#    'rank': 1946,
#    'is_active': 1,
#    'first_historical_data': '2014-11-08T22:54:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:09.000Z',
#    'platform': None},
#   {'id': 720,
#    'name': 'Crown',
#    'symbol': 'CRW',
#    'slug': 'crown',
#    'rank': 1674,
#    'is_active': 1,
#    'first_historical_data': '2014-11-08T22:54:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 730,
#    'name': 'GCN Coin',
#    'symbol': 'GCN',
#    'slug': 'gcn-coin',
#    'rank': 2372,
#    'is_active': 1,
#    'first_historical_data': '2014-11-16T23:54:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 733,
#    'name': 'Quotient',
#    'symbol': 'XQN',
#    'slug': 'quotient',
#    'rank': 6326,
#    'is_active': 1,
#    'first_historical_data': '2014-11-23T20:09:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 760,
#    'name': 'OKCash',
#    'symbol': 'OK',
#    'slug': 'okcash',
#    'rank': 1626,
#    'is_active': 1,
#    'first_historical_data': '2014-12-14T03:29:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 764,
#    'name': 'PayCoin',
#    'symbol': 'XPY',
#    'slug': 'paycoin2',
#    'rank': 2329,
#    'is_active': 1,
#    'first_historical_data': '2014-12-16T05:34:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 788,
#    'name': 'Circuits of Value',
#    'symbol': 'COVAL',
#    'slug': 'circuits-of-value',
#    'rank': 1030,
#    'is_active': 1,
#    'first_historical_data': '2015-01-23T13:39:23.000Z',
#    'last_historical_data': '2021-11-07T00:39:09.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x3d658390460295fb963f54dc0899cfb1c30776df'}},
#   {'id': 789,
#    'name': 'Nexus',
#    'symbol': 'NXS',
#    'slug': 'nexus',
#    'rank': 646,
#    'is_active': 1,
#    'first_historical_data': '2015-01-25T18:54:23.000Z',
#    'last_historical_data': '2021-11-07T00:39:15.000Z',
#    'platform': None},
#   {'id': 799,
#    'name': 'SmileyCoin',
#    'symbol': 'SMLY',
#    'slug': 'smileycoin',
#    'rank': 2008,
#    'is_active': 1,
#    'first_historical_data': '2015-01-28T04:49:22.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 815,
#    'name': 'Kobocoin',
#    'symbol': 'KOBO',
#    'slug': 'kobocoin',
#    'rank': 1997,
#    'is_active': 1,
#    'first_historical_data': '2015-02-15T15:14:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:07.000Z',
#    'platform': None},
#   {'id': 819,
#    'name': 'Bean Cash',
#    'symbol': 'BITB',
#    'slug': 'bean-cash',
#    'rank': 1551,
#    'is_active': 1,
#    'first_historical_data': '2015-02-18T13:19:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:14.000Z',
#    'platform': None},
#   {'id': 823,
#    'name': 'GeoCoin',
#    'symbol': 'GEO',
#    'slug': 'geocoin',
#    'rank': 1909,
#    'is_active': 1,
#    'first_historical_data': '2015-02-22T02:14:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 825,
#    'name': 'Tether',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'rank': 5,
#    'is_active': 1,
#    'first_historical_data': '2015-02-25T13:34:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'}},
#   {'id': 831,
#    'name': 'Wild Beast Block',
#    'symbol': 'WBB',
#    'slug': 'wild-beast-block',
#    'rank': 2668,
#    'is_active': 1,
#    'first_historical_data': '2015-02-28T17:14:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:17.000Z',
#    'platform': None},
#   {'id': 833,
#    'name': 'Gridcoin',
#    'symbol': 'GRC',
#    'slug': 'gridcoin',
#    'rank': 1491,
#    'is_active': 1,
#    'first_historical_data': '2015-02-28T18:24:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:15.000Z',
#    'platform': None},
#   {'id': 837,
#    'name': 'X-Coin',
#    'symbol': 'XCO',
#    'slug': 'x-coin',
#    'rank': 2567,
#    'is_active': 1,
#    'first_historical_data': '2015-03-06T04:34:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:12.000Z',
#    'platform': None},
#   {'id': 857,
#    'name': 'SongCoin',
#    'symbol': 'SONG',
#    'slug': 'songcoin',
#    'rank': 2605,
#    'is_active': 1,
#    'first_historical_data': '2015-03-23T01:59:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:17.000Z',
#    'platform': None},
#   {'id': 859,
#    'name': 'Woodcoin',
#    'symbol': 'LOG',
#    'slug': 'woodcoin',
#    'rank': 1959,
#    'is_active': 1,
#    'first_historical_data': '2015-03-23T02:04:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 873,
#    'name': 'NEM',
#    'symbol': 'XEM',
#    'slug': 'nem',
#    'rank': 76,
#    'is_active': 1,
#    'first_historical_data': '2015-04-01T00:29:41.000Z',
#    'last_historical_data': '2021-11-07T00:39:17.000Z',
#    'platform': None},
#   {'id': 894,
#    'name': 'Neutron',
#    'symbol': 'NTRN',
#    'slug': 'neutron',
#    'rank': 2489,
#    'is_active': 1,
#    'first_historical_data': '2015-04-21T12:14:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 895,
#    'name': 'Xaurum',
#    'symbol': 'XAUR',
#    'slug': 'xaurum',
#    'rank': 1785,
#    'is_active': 1,
#    'first_historical_data': '2015-04-21T12:19:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:17.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4DF812F6064def1e5e029f1ca858777CC98D2D81'}},
#   {'id': 898,
#    'name': 'Californium',
#    'symbol': 'CF',
#    'slug': 'californium',
#    'rank': 2590,
#    'is_active': 1,
#    'first_historical_data': '2015-04-21T12:14:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:08.000Z',
#    'platform': None},
#   {'id': 911,
#    'name': 'Advanced Internet Blocks',
#    'symbol': 'AIB',
#    'slug': 'advanced-internet-blocks',
#    'rank': 5325,
#    'is_active': 1,
#    'first_historical_data': '2015-04-30T04:24:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 914,
#    'name': 'Sphere',
#    'symbol': 'SPHR',
#    'slug': 'sphere',
#    'rank': 5264,
#    'is_active': 1,
#    'first_historical_data': '2015-05-02T15:49:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:19.000Z',
#    'platform': None},
#   {'id': 916,
#    'name': 'MedicCoin',
#    'symbol': 'MEDIC',
#    'slug': 'mediccoin',
#    'rank': 2535,
#    'is_active': 1,
#    'first_historical_data': '2015-05-04T03:19:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:19.000Z',
#    'platform': None},
#   {'id': 918,
#    'name': 'Bubble',
#    'symbol': 'BUB',
#    'slug': 'bubble',
#    'rank': 6327,
#    'is_active': 1,
#    'first_historical_data': '2015-05-07T03:04:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 921,
#    'name': 'Universal Currency',
#    'symbol': 'UNIT',
#    'slug': 'universal-currency',
#    'rank': 2298,
#    'is_active': 1,
#    'first_historical_data': '2015-05-07T03:04:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 934,
#    'name': 'ParkByte',
#    'symbol': 'PKB',
#    'slug': 'parkbyte',
#    'rank': 2559,
#    'is_active': 1,
#    'first_historical_data': '2015-05-19T00:34:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 938,
#    'name': 'ARbit',
#    'symbol': 'ARB',
#    'slug': 'arbit',
#    'rank': 2492,
#    'is_active': 1,
#    'first_historical_data': '2015-05-21T04:14:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 945,
#    'name': 'Bata',
#    'symbol': 'BTA',
#    'slug': 'bata',
#    'rank': 2445,
#    'is_active': 1,
#    'first_historical_data': '2015-05-29T11:44:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:10.000Z',
#    'platform': None},
#   {'id': 948,
#    'name': 'AudioCoin',
#    'symbol': 'ADC',
#    'slug': 'audiocoin',
#    'rank': 2016,
#    'is_active': 1,
#    'first_historical_data': '2015-06-05T12:59:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 951,
#    'name': 'Synergy',
#    'symbol': 'SNRG',
#    'slug': 'synergy',
#    'rank': 2310,
#    'is_active': 1,
#    'first_historical_data': '2015-06-08T04:44:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:19.000Z',
#    'platform': None},
#   {'id': 960,
#    'name': 'FujiCoin',
#    'symbol': 'FJC',
#    'slug': 'fujicoin',
#    'rank': 1584,
#    'is_active': 1,
#    'first_historical_data': '2015-06-14T16:54:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 977,
#    'name': 'GravityCoin',
#    'symbol': 'GXX',
#    'slug': 'gravitycoin',
#    'rank': 2671,
#    'is_active': 1,
#    'first_historical_data': '2015-06-26T12:34:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:09.000Z',
#    'platform': None},
#   {'id': 978,
#    'name': 'Ratecoin',
#    'symbol': 'XRA',
#    'slug': 'ratecoin',
#    'rank': 2326,
#    'is_active': 1,
#    'first_historical_data': '2015-06-26T12:34:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:19.000Z',
#    'platform': None},
#   {'id': 986,
#    'name': 'CrevaCoin',
#    'symbol': 'CREVA',
#    'slug': 'crevacoin',
#    'rank': 2594,
#    'is_active': 1,
#    'first_historical_data': '2015-07-07T15:49:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:20.000Z',
#    'platform': None},
#   {'id': 990,
#    'name': 'Bitzeny',
#    'symbol': 'ZNY',
#    'slug': 'bitzeny',
#    'rank': 2255,
#    'is_active': 1,
#    'first_historical_data': '2015-07-09T15:34:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:20.000Z',
#    'platform': None},
#   {'id': 993,
#    'name': 'BowsCoin',
#    'symbol': 'BSC',
#    'slug': 'bowscoin',
#    'rank': 2573,
#    'is_active': 1,
#    'first_historical_data': '2015-07-13T20:39:31.000Z',
#    'last_historical_data': '2021-11-07T00:39:19.000Z',
#    'platform': None},
#   {'id': 1004,
#    'name': 'HNC COIN',
#    'symbol': 'HNC',
#    'slug': 'hnccoin',
#    'rank': 4873,
#    'is_active': 1,
#    'first_historical_data': '2015-07-21T16:39:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:19.000Z',
#    'platform': None},
#   {'id': 1019,
#    'name': 'Manna',
#    'symbol': 'MANNA',
#    'slug': 'manna',
#    'rank': 1938,
#    'is_active': 1,
#    'first_historical_data': '2015-07-27T15:54:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:18.000Z',
#    'platform': None},
#   {'id': 1020,
#    'name': 'Axiom',
#    'symbol': 'AXIOM',
#    'slug': 'axiom',
#    'rank': 6328,
#    'is_active': 1,
#    'first_historical_data': '2015-07-30T03:04:30.000Z',
#    'last_historical_data': '2021-11-07T00:39:19.000Z',
#    'platform': None},
#   {'id': 1026,
#    'name': 'Aeon',
#    'symbol': 'AEON',
#    'slug': 'aeon',
#    'rank': 1262,
#    'is_active': 1,
#    'first_historical_data': '2015-08-04T18:09:29.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'rank': 2,
#    'is_active': 1,
#    'first_historical_data': '2015-08-07T14:49:30.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1032,
#    'name': 'TransferCoin',
#    'symbol': 'TX',
#    'slug': 'transfercoin',
#    'rank': 1398,
#    'is_active': 1,
#    'first_historical_data': '2015-08-21T02:09:30.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1033,
#    'name': 'GuccioneCoin',
#    'symbol': 'GCC',
#    'slug': 'guccionecoin',
#    'rank': 2442,
#    'is_active': 1,
#    'first_historical_data': '2015-08-21T02:09:30.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1035,
#    'name': 'AmsterdamCoin',
#    'symbol': 'AMS',
#    'slug': 'amsterdamcoin',
#    'rank': 2565,
#    'is_active': 1,
#    'first_historical_data': '2015-08-21T02:09:30.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1037,
#    'name': 'Agoras',
#    'symbol': 'AGRS',
#    'slug': 'agoras-tokens',
#    'rank': 1093,
#    'is_active': 1,
#    'first_historical_data': '2015-08-24T02:49:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x738865301a9b7dd80dc3666dd48cf034ec42bdda'}},
#   {'id': 1038,
#    'name': 'Eurocoin',
#    'symbol': 'EUC',
#    'slug': 'eurocoin',
#    'rank': 2588,
#    'is_active': 1,
#    'first_historical_data': '2015-08-24T02:49:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1042,
#    'name': 'Siacoin',
#    'symbol': 'SC',
#    'slug': 'siacoin',
#    'rank': 109,
#    'is_active': 1,
#    'first_historical_data': '2015-08-26T18:19:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1044,
#    'name': 'Global Currency Reserve',
#    'symbol': 'GCR',
#    'slug': 'global-currency-reserve',
#    'rank': 2460,
#    'is_active': 1,
#    'first_historical_data': '2015-08-26T18:19:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1052,
#    'name': 'VectorAI',
#    'symbol': 'VEC2',
#    'slug': 'vector',
#    'rank': 2646,
#    'is_active': 1,
#    'first_historical_data': '2015-09-04T16:39:29.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1053,
#    'name': 'Bolivarcoin',
#    'symbol': 'BOLI',
#    'slug': 'bolivarcoin',
#    'rank': 2406,
#    'is_active': 1,
#    'first_historical_data': '2015-09-08T21:29:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1066,
#    'name': 'Pakcoin',
#    'symbol': 'PAK',
#    'slug': 'pakcoin',
#    'rank': 2151,
#    'is_active': 1,
#    'first_historical_data': '2015-09-15T20:04:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 1070,
#    'name': 'Expanse',
#    'symbol': 'EXP',
#    'slug': 'expanse',
#    'rank': 1874,
#    'is_active': 1,
#    'first_historical_data': '2015-09-15T20:04:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1082,
#    'name': 'SIBCoin',
#    'symbol': 'SIB',
#    'slug': 'sibcoin',
#    'rank': 2000,
#    'is_active': 1,
#    'first_historical_data': '2015-09-25T22:19:29.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1085,
#    'name': 'Swing',
#    'symbol': 'SWING',
#    'slug': 'swing',
#    'rank': 2126,
#    'is_active': 1,
#    'first_historical_data': '2015-09-28T15:44:31.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1087,
#    'name': 'Factom',
#    'symbol': 'FCT',
#    'slug': 'factom',
#    'rank': 947,
#    'is_active': 1,
#    'first_historical_data': '2015-10-06T01:34:29.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1089,
#    'name': 'ParallelCoin',
#    'symbol': 'DUO',
#    'slug': 'parallelcoin',
#    'rank': 2570,
#    'is_active': 1,
#    'first_historical_data': '2015-10-24T16:24:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1090,
#    'name': 'Save and Gain',
#    'symbol': 'SANDG',
#    'slug': 'save-and-gain',
#    'rank': 2685,
#    'is_active': 1,
#    'first_historical_data': '2015-10-12T16:30:37.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1104,
#    'name': 'Augur',
#    'symbol': 'REP',
#    'slug': 'augur',
#    'rank': 199,
#    'is_active': 1,
#    'first_historical_data': '2015-10-27T17:14:30.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1985365e9f78359a9B6AD760e32412f4a445E862'}},
#   {'id': 1106,
#    'name': 'StrongHands',
#    'symbol': 'SHND',
#    'slug': 'stronghands',
#    'rank': 2087,
#    'is_active': 1,
#    'first_historical_data': '2015-10-30T18:09:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1107,
#    'name': 'PAC Protocol',
#    'symbol': 'PAC',
#    'slug': 'pac-protocol',
#    'rank': 522,
#    'is_active': 1,
#    'first_historical_data': '2015-11-02T21:59:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1120,
#    'name': 'DraftCoin',
#    'symbol': 'DFT',
#    'slug': 'draftcoin',
#    'rank': 2314,
#    'is_active': 1,
#    'first_historical_data': '2015-11-23T19:59:28.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 1135,
#    'name': 'ClubCoin',
#    'symbol': 'CLUB',
#    'slug': 'clubcoin',
#    'rank': 6329,
#    'is_active': 1,
#    'first_historical_data': '2015-12-21T17:49:32.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
# ...
#    'rank': 226,
#    'is_active': 1,
#    'first_historical_data': '2018-08-06T21:24:24.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xc9859fccc876e6b4b3c749c5d29ea04f48acb74f'}},
#   {'id': 3087,
#    'name': 'CROAT',
#    'symbol': 'CROAT',
#    'slug': 'croat',
#    'rank': 2138,
#    'is_active': 1,
#    'first_historical_data': '2018-08-06T21:24:24.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 3092,
#    'name': 'Nuggets',
#    'symbol': 'NUG',
#    'slug': 'nuggets',
#    'rank': 1886,
#    'is_active': 1,
#    'first_historical_data': '2018-08-07T22:34:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x245ef47d4d0505ecf3ac463f4d81f41ade8f1fd1'}},
#   {'id': 3093,
#    'name': 'BBSCoin',
#    'symbol': 'BBS',
#    'slug': 'bbscoin',
#    'rank': 2466,
#    'is_active': 1,
#    'first_historical_data': '2018-08-30T02:04:17.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 3094,
#    'name': 'Scorum Coins',
#    'symbol': 'SCR',
#    'slug': 'scorum-coins',
#    'rank': 1784,
#    'is_active': 1,
#    'first_historical_data': '2018-08-07T22:34:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3095,
#    'name': 'Niobium Coin',
#    'symbol': 'NBC',
#    'slug': 'niobium-coin',
#    'rank': 2111,
#    'is_active': 1,
#    'first_historical_data': '2018-08-06T20:59:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9f195617fa8fbad9540c5d113a99a0a0172aaedc'}},
#   {'id': 3096,
#    'name': 'Pundi X NEM',
#    'symbol': 'NPXSXEM',
#    'slug': 'pundi-x-nem',
#    'rank': 1466,
#    'is_active': 1,
#    'first_historical_data': '2018-08-07T22:34:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1839,
#     'name': 'Binance Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'binance-coin',
#     'token_address': 'NPXSXEM-89C'}},
#   {'id': 3097,
#    'name': 'XOVBank',
#    'symbol': 'XOV',
#    'slug': 'xovbank',
#    'rank': 2493,
#    'is_active': 1,
#    'first_historical_data': '2018-08-06T21:14:19.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x153ed9cc1b792979d2bde0bbf45cc2a7e436a5f9'}},
#   {'id': 3101,
#    'name': 'OptiToken',
#    'symbol': 'OPTI',
#    'slug': 'optitoken',
#    'rank': 2292,
#    'is_active': 1,
#    'first_historical_data': '2018-08-07T22:34:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x832904863978b94802123106e6eb491bdf0df928'}},
#   {'id': 3104,
#    'name': 'Giant',
#    'symbol': 'GIC',
#    'slug': 'giant-coin',
#    'rank': 2642,
#    'is_active': 1,
#    'first_historical_data': '2018-08-07T23:24:23.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': None},
#   {'id': 3106,
#    'name': 'PKG Token',
#    'symbol': 'PKG',
#    'slug': 'pkg-token',
#    'rank': 2052,
#    'is_active': 1,
#    'first_historical_data': '2018-08-08T16:54:20.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x02f2d4a04e6e01ace88bd2cd632875543b2ef577'}},
#   {'id': 3112,
#    'name': 'Bitnation',
#    'symbol': 'XPAT',
#    'slug': 'bitnation',
#    'rank': 2405,
#    'is_active': 1,
#    'first_historical_data': '2018-08-07T22:34:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xBB1fA4FdEB3459733bF67EbC6f893003fA976a82'}},
#   {'id': 3116,
#    'name': 'Insight Chain',
#    'symbol': 'INB',
#    'slug': 'insight-chain',
#    'rank': 6349,
#    'is_active': 1,
#    'first_historical_data': '2018-08-08T16:49:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:02.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x17aa18a4b64a55abed7fa543f2ba4e91f2dce482'}},
#   {'id': 3118,
#    'name': 'Graviocoin',
#    'symbol': 'GIO',
#    'slug': 'graviocoin',
#    'rank': 1436,
#    'is_active': 1,
#    'first_historical_data': '2018-08-07T23:34:21.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3119,
#    'name': 'Alchemint Standards',
#    'symbol': 'SDS',
#    'slug': 'alchemint-standards',
#    'rank': 2571,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T23:19:24.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1376,
#     'name': 'Neo',
#     'symbol': 'NEO',
#     'slug': 'neo',
#     'token_address': '6fad54d8cc692fc808fd97a207836a846c217705'}},
#   {'id': 3120,
#    'name': 'OWNDATA',
#    'symbol': 'OWN',
#    'slug': 'owndata',
#    'rank': 2059,
#    'is_active': 1,
#    'first_historical_data': '2018-08-08T16:49:23.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x170b275ced089fffaebfe927f445a350ed9160dc'}},
#   {'id': 3121,
#    'name': 'IGToken',
#    'symbol': 'IG',
#    'slug': 'igtoken',
#    'rank': 2534,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T23:14:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8a88f04e0c905054d2f33b26bb3a46d7091a039a'}},
#   {'id': 3123,
#    'name': 'GSENetwork',
#    'symbol': 'GSE',
#    'slug': 'gsenetwork',
#    'rank': 4577,
#    'is_active': 1,
#    'first_historical_data': '2018-08-08T18:39:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xe530441f4f73bDB6DC2fA5aF7c3fC5fD551Ec838'}},
#   {'id': 3125,
#    'name': 'XDNA',
#    'symbol': 'XDNA',
#    'slug': 'xdna',
#    'rank': 2667,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T23:14:24.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3126,
#    'name': 'ProximaX',
#    'symbol': 'XPX',
#    'slug': 'proximax',
#    'rank': 1207,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T00:14:17.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3127,
#    'name': 'Themis',
#    'symbol': 'GET',
#    'slug': 'themis',
#    'rank': 1955,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T23:24:23.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x60c68a87be1e8a84144b543aacfa77199cd3d024'}},
#   {'id': 3128,
#    'name': 'SiaCashCoin',
#    'symbol': 'SCC',
#    'slug': 'siacashcoin',
#    'rank': 2383,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T23:14:24.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x74fd51a98a4a1ecbef8cc43be801cce630e260bd'}},
#   {'id': 3129,
#    'name': 'Nyerium',
#    'symbol': 'NYEX',
#    'slug': 'nyerium',
#    'rank': 2603,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T23:14:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3131,
#    'name': 'Thingschain',
#    'symbol': 'TIC',
#    'slug': 'thingschain',
#    'rank': 2527,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T23:14:25.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x72430a612adc007c50e3b6946dbb1bb0fd3101d1'}},
#   {'id': 3132,
#    'name': 'EtherGem',
#    'symbol': 'EGEM',
#    'slug': 'ethergem',
#    'rank': 2001,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T23:14:29.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3133,
#    'name': 'Arepacoin',
#    'symbol': 'AREPA',
#    'slug': 'arepacoin',
#    'rank': 2530,
#    'is_active': 1,
#    'first_historical_data': '2018-08-09T23:14:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3136,
#    'name': 'MEET.ONE',
#    'symbol': 'MEETONE',
#    'slug': 'meetone',
#    'rank': 1515,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:29:26.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1839,
#     'name': 'Binance Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'binance-coin',
#     'token_address': 'MEETONE-031'}},
#   {'id': 3137,
#    'name': 'KARMA',
#    'symbol': 'KARMA',
#    'slug': 'karma-eos',
#    'rank': 693,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:29:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1765,
#     'name': 'EOS',
#     'symbol': 'EOS',
#     'slug': 'eos',
#     'token_address': 'therealkarma'}},
#   {'id': 3139,
#    'name': 'DxChain Token',
#    'symbol': 'DX',
#    'slug': 'dxchain-token',
#    'rank': 713,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:29:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x973e52691176d36453868D9d86572788d27041A9'}},
#   {'id': 3140,
#    'name': 'Ubex',
#    'symbol': 'UBEX',
#    'slug': 'ubex',
#    'rank': 1730,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T20:04:34.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6704b673c70de9bf74c8fba4b4bd748f0e2190e1'}},
#   {'id': 3141,
#    'name': 'Blockpass',
#    'symbol': 'PASS',
#    'slug': 'blockpass',
#    'rank': 2099,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:24:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xee4458e052b533b1aabd493b5f8c4d85d7b263dc'}},
#   {'id': 3142,
#    'name': 'BaaSid',
#    'symbol': 'BAAS',
#    'slug': 'baasid',
#    'rank': 1056,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:24:30.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x5d929AA919E489505CcAAd8A199619c6DCA0c2de'}},
#   {'id': 3144,
#    'name': 'ThoreCoin',
#    'symbol': 'THR',
#    'slug': 'thorecoin',
#    'rank': 5643,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:29:30.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3147,
#    'name': 'HYCON',
#    'symbol': 'HYC',
#    'slug': 'hycon',
#    'rank': 1961,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:29:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3148,
#    'name': 'MetaMorph',
#    'symbol': 'METM',
#    'slug': 'metamorph',
#    'rank': 2112,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T20:09:32.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xfef3884b603c33ef8ed4183346e093a173c94da6'}},
#   {'id': 3149,
#    'name': 'Netkoin',
#    'symbol': 'NTK',
#    'slug': 'netkoin',
#    'rank': 6311,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:29:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x5d4d57cd06fa7fe99e26fdc481b468f77f05073c'}},
#   {'id': 3151,
#    'name': 'Akroma',
#    'symbol': 'AKA',
#    'slug': 'akroma',
#    'rank': 2479,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T22:09:29.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3152,
#    'name': 'Obitan Chain',
#    'symbol': 'OBTC',
#    'slug': 'obitan-chain',
#    'rank': 6350,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:29:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x8fC01E6CbDfFaf09B54F423f9Bb1F856b22e47b2'}},
#   {'id': 3154,
#    'name': 'Davinci Coin',
#    'symbol': 'DAC',
#    'slug': 'davinci-coin',
#    'rank': 1127,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T20:09:34.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xaad54c9f27b876d2538455dda69207279ff673a5'}},
#   {'id': 3155,
#    'name': 'Quant',
#    'symbol': 'QNT',
#    'slug': 'quant',
#    'rank': 56,
#    'is_active': 1,
#    'first_historical_data': '2018-08-10T20:29:27.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4a220e6096b25eadb88358cb44068a3248254675'}},
#   {'id': 3156,
#    'name': 'Airbloc',
#    'symbol': 'ABL',
#    'slug': 'airbloc',
#    'rank': 1236,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T20:04:34.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xf8b358b3397a8ea5464f8cc753645d42e14b79ea'}},
#   {'id': 3158,
#    'name': 'ZCore',
#    'symbol': 'ZCR',
#    'slug': 'zcore',
#    'rank': 2386,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T20:44:31.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3159,
#    'name': 'Apollon',
#    'symbol': 'XAP',
#    'slug': 'apollon',
#    'rank': 2664,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T20:54:31.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3162,
#    'name': 'YoloCash',
#    'symbol': 'YLC',
#    'slug': 'yolocash',
#    'rank': 2518,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T23:39:32.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x21d5678a62dfe63a47062469ebb2fac2817d8832'}},
#   {'id': 3164,
#    'name': 'PumaPay',
#    'symbol': 'PMA',
#    'slug': 'pumapay',
#    'rank': 1297,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T23:39:32.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x846c66cf71c43f80403b51fe3906b3599d63336f'}},
#   {'id': 3165,
#    'name': 'Arion',
#    'symbol': 'ARION',
#    'slug': 'arion',
#    'rank': 2515,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T23:39:32.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   {'id': 3166,
#    'name': 'Bitcoin Incognito',
#    'symbol': 'XBI',
#    'slug': 'bitcoin-incognito',
#    'rank': 2411,
#    'is_active': 1,
#    'first_historical_data': '2018-08-13T23:49:32.000Z',
#    'last_historical_data': '2021-11-07T00:39:03.000Z',
#    'platform': None},
#   ...]}

# %% [markdown]
# Example of a cryptocurrency quote for Bitcoin:

# %%
btc_data["data"]
# Out:
# {'1': {'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 8291,
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'store-of-value',
#    'state-channels',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'arrington-xrp-capital',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures',
#    'galaxy-digital-portfolio',
#    'huobi-capital',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-xzy-screener'],
#   'max_supply': 21000000,
#   'circulating_supply': 18865956,
#   'total_supply': 18865956,
#   'platform': None,
#   'cmc_rank': 1,
#   'last_updated': '2021-11-07T00:55:02.000Z',
#   'quote': {'USD': {'price': 61566.158991048,
#     'volume_24h': 26565737434.931507,
#     'volume_change_24h': -13.1339,
#     'percent_change_1h': 0.11789035,
#     'percent_change_24h': 0.54129885,
#     'percent_change_7d': -1.11786861,
#     'percent_change_30d': 13.73788508,
#     'percent_change_60d': 30.64806768,
#     'percent_change_90d': 42.41792716,
#     'market_cap': 1161504446614.116,
#     'market_cap_dominance': 42.5291,
#     'fully_diluted_market_cap': 1292889338812.01,
#     'market_cap_by_total_supply': 1161504446614.116,
#     'last_updated': '2021-11-07T00:55:02.000Z'}}}}

# %% [markdown]
# # Get the ids for the coins available in EToro from map_data

# %% [markdown]
# ### Get relevant fields ("id", "symbol", "name") from map_data

# %%
map_data_copy = []
map_data_copy += [map_data["data"][i][key] for i in range(len(map_data["data"])) for key in ["id","symbol","name"]]

# %% [markdown]
# ### Group data in lists of lists

# %%
new_data = []
new_data += [map_data_copy[i:i+3] for i in range(0, len(map_data_copy)-2, 3)]

# %%
new_data[:10]
# Out:
# [[1, 'BTC', 'Bitcoin'],
#  [2, 'LTC', 'Litecoin'],
#  [3, 'NMC', 'Namecoin'],
#  [4, 'TRC', 'Terracoin'],
#  [5, 'PPC', 'Peercoin'],
#  [6, 'NVC', 'Novacoin'],
#  [8, 'FTC', 'Feathercoin'],
#  [10, 'FRC', 'Freicoin'],
#  [13, 'IXC', 'Ixcoin'],
#  [16, 'WDC', 'WorldCoin']]

# %% [markdown]
# ### Put this in a PandasDataframe for ease of use

# %%
map_df = pd.DataFrame(new_data, columns=["id","Symbol","Name"])
map_df.head()
# Out:
#    id Symbol       Name
# 0   1    BTC    Bitcoin
# 1   2    LTC   Litecoin
# 2   3    NMC   Namecoin
# 3   4    TRC  Terracoin
# 4   5    PPC   Peercoin

# %% [markdown]
# ### Use the coin names contained in the coin_names list to get the ids for coins that are available on Etoro

# %%
coin_names.rename(columns={"Ticker":"Symbol"}, inplace=True)
coin_names.head()
# Out:
#   Symbol
# 0    BTC
# 1    ETH
# 2    BCH
# 3    XRP
# 4   DASH

# %% [markdown]
# ### Merge dataframes on the Symbol column

# %%
merged_df = pd.merge(map_df, coin_names, on='Symbol')

# %%
merged_df
# Out:
#        id Symbol                   Name
# 0       1    BTC                Bitcoin
# 1       2    LTC               Litecoin
# 2      52    XRP                    XRP
# 3      74   DOGE               Dogecoin
# 4     131   DASH                   Dash
# 5     512    XLM                Stellar
# 6    1027    ETH               Ethereum
# 7    1321    ETC       Ethereum Classic
# 8    1376    NEO                    Neo
# 9    1437    ZEC                  Zcash
# 10   1518    MKR                  Maker
# 11   1697    BAT  Basic Attention Token
# 12   1720  MIOTA                   IOTA
# 13   1765    EOS                    EOS
# 14   1831    BCH           Bitcoin Cash
# 15   1839    BNB           Binance Coin
# 16   1958    TRX                   TRON
# 17   1966   MANA           Decentraland
# 18  12712   MANA           Genesis Mana
# 19   1975   LINK              Chainlink
# 20   2010    ADA                Cardano
# 21   2011    XTZ                  Tezos
# 22   2130    ENJ             Enjin Coin
# 23   2280    FIL               Filecoin
# 24   3180   COMP          Compound Coin
# 25   5692   COMP               Compound
# 26   3794   ATOM                 Cosmos
# 27   3890  MATIC                Polygon
# 28   4030   ALGO               Algorand
# 29   4307    UNI          UNICORN Token
# 30   7083    UNI                Uniswap
# 31   5426    SOL                 Solana
# 32  12003    SOL   SOL RUNE - Rune.Game
# 33   5711    GRT     Golden Ratio Token
# 34   6719    GRT              The Graph
# 35   5864    YFI          yearn.finance
# 36   6538    CRV        Curve DAO Token
# 37   6636    DOT               Polkadot
# 38   7278   AAVE                   Aave
# 39   8104  1INCH          1inch Network

# %% [markdown]
# ### Get all ids into a single string

# %%
id_list = [id for id in merged_df[["id"]].iloc[:,0]]

# %%
id_string = ""
#get all ids in one string
for id in id_list:
    id_string += str(id) + ","
    
#remove last comma
id_string = id_string.strip(",")

# %% [markdown]
# ### Call API with all relevant IDs

# %%
url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/quotes/latest"

parameters = {
  'id':f'{id_string}',
  'convert':'USD',
  'aux': 'num_market_pairs,cmc_rank,tags,platform,max_supply,circulating_supply,total_supply,market_cap_by_total_supply'
}

coin_quotes = cmc_api(url, parameters)

# %%
coin_quotes
# Out:
# {'status': {'timestamp': '2021-11-07T15:29:37.886Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 13,
#   'credit_count': 1,
#   'notice': None},
#  'data': {'1': {'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 8291,
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channels',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'arrington-xrp-capital',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures',
#     'galaxy-digital-portfolio',
#     'huobi-capital',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-xzy-screener'],
#    'max_supply': 21000000,
#    'circulating_supply': 18866462,
#    'total_supply': 18866462,
#    'platform': None,
#    'cmc_rank': 1,
#    'last_updated': '2021-11-07T15:28:02.000Z',
#    'quote': {'USD': {'price': 61817.78239076061,
#      'volume_24h': 25038723279.23909,
#      'volume_change_24h': -17.0438,
#      'percent_change_1h': -0.39430395,
#      'percent_change_24h': 1.78396473,
#      'percent_change_7d': 1.77794044,
#      'percent_change_30d': 13.25700736,
#      'percent_change_60d': 34.02405551,
#      'percent_change_90d': 34.53747557,
#      'market_cap': 1166282842399.5542,
#      'market_cap_dominance': 42.204,
#      'fully_diluted_market_cap': 1298173430205.97,
#      'market_cap_by_total_supply': 1166282842399.5542,
#      'last_updated': '2021-11-07T15:28:02.000Z'}}},
#   '2': {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'num_market_pairs': 693,
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'binance-chain',
#     'binance-smart-chain'],
#    'max_supply': 84000000,
#    'circulating_supply': 68920082.61947674,
#    'total_supply': 84000000,
#    'platform': None,
#    'cmc_rank': 17,
#    'last_updated': '2021-11-07T15:28:02.000Z',
#    'quote': {'USD': {'price': 199.67508544626386,
#      'volume_24h': 1354702269.6045868,
#      'volume_change_24h': -14.8736,
#      'percent_change_1h': -0.10227462,
#      'percent_change_24h': 2.41245627,
#      'percent_change_7d': 5.14942138,
#      'percent_change_30d': 9.70080173,
#      'percent_change_60d': 10.28473558,
#      'percent_change_90d': 21.87094183,
#      'market_cap': 13761623386.007582,
#      'market_cap_dominance': 0.4978,
#      'fully_diluted_market_cap': 16772707177.49,
#      'market_cap_by_total_supply': 16772707177.486164,
#      'last_updated': '2021-11-07T15:28:02.000Z'}}},
#   '52': {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'num_market_pairs': 635,
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'binance-chain',
#     'arrington-xrp-capital',
#     'galaxy-digital-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio'],
#    'max_supply': 100000000000,
#    'circulating_supply': 47081679946,
#    'total_supply': 99990161790,
#    'platform': None,
#    'cmc_rank': 7,
#    'last_updated': '2021-11-07T15:28:03.000Z',
#    'quote': {'USD': {'price': 1.21090065523293,
#      'volume_24h': 2851808586.443647,
#      'volume_change_24h': -6.3259,
#      'percent_change_1h': -0.05903268,
#      'percent_change_24h': 6.33864669,
#      'percent_change_7d': 10.86896344,
#      'percent_change_30d': 12.47919347,
#      'percent_change_60d': 9.98100668,
#      'percent_change_90d': 47.53294577,
#      'market_cap': 57011237096.0785,
#      'market_cap_dominance': 2.0632,
#      'fully_diluted_market_cap': 121090065523.29,
#      'market_cap_by_total_supply': 121078152428.35768,
#      'last_updated': '2021-11-07T15:28:03.000Z'}}},
#   '74': {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'num_market_pairs': 401,
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'memes',
#     'payments',
#     'binance-smart-chain',
#     'doggone-doggerel'],
#    'max_supply': None,
#    'circulating_supply': 132011346979.6624,
#    'total_supply': 132011346979.6624,
#    'platform': None,
#    'cmc_rank': 9,
#    'last_updated': '2021-11-07T15:28:03.000Z',
#    'quote': {'USD': {'price': 0.26491235740698,
#      'volume_24h': 1102478569.193879,
#      'volume_change_24h': -19.5285,
#      'percent_change_1h': -0.37200893,
#      'percent_change_24h': 2.96309197,
#      'percent_change_7d': 1.86983944,
#      'percent_change_30d': 7.1993224,
#      'percent_change_60d': 6.15064986,
#      'percent_change_90d': 4.05685171,
#      'market_cap': 34971437132.85317,
#      'market_cap_dominance': 1.2656,
#      'fully_diluted_market_cap': 34971437132.85,
#      'market_cap_by_total_supply': 34971437132.85317,
#      'last_updated': '2021-11-07T15:28:03.000Z'}}},
#   '131': {'id': 131,
#    'name': 'Dash',
#    'symbol': 'DASH',
#    'slug': 'dash',
#    'num_market_pairs': 307,
#    'tags': ['mineable',
#     'hybrid-pow-pos',
#     'x11',
#     'medium-of-exchange',
#     'masternodes',
#     'dao',
#     'governance'],
#    'max_supply': 18900000,
#    'circulating_supply': 10419231.10545561,
#    'total_supply': 10419231.10545561,
#    'platform': None,
#    'cmc_rank': 74,
#    'last_updated': '2021-11-07T15:28:03.000Z',
#    'quote': {'USD': {'price': 192.97212111812073,
#      'volume_24h': 191847328.42721605,
#      'volume_change_24h': -17.3986,
#      'percent_change_1h': 0.07101938,
#      'percent_change_24h': 1.88422848,
#      'percent_change_7d': 0.46861214,
#      'percent_change_30d': 0.67632069,
#      'percent_change_60d': -4.20314662,
#      'percent_change_90d': 12.9576597,
#      'market_cap': 2010621126.8396711,
#      'market_cap_dominance': 0.0728,
#      'fully_diluted_market_cap': 3647173089.13,
#      'market_cap_by_total_supply': 2010621126.8396711,
#      'last_updated': '2021-11-07T15:28:03.000Z'}}},
#   '512': {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'num_market_pairs': 370,
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'decentralized-exchange',
#     'smart-contracts',
#     'hashkey-capital-portfolio'],
#    'max_supply': 50001806812,
#    'circulating_supply': 24206603022.60365,
#    'total_supply': 50001802643.976524,
#    'platform': None,
#    'cmc_rank': 25,
#    'last_updated': '2021-11-07T15:28:06.000Z',
#    'quote': {'USD': {'price': 0.36248970160691,
#      'volume_24h': 410164026.0481368,
#      'volume_change_24h': -10.243,
#      'percent_change_1h': -0.54581768,
#      'percent_change_24h': 2.73642344,
#      'percent_change_7d': -2.68557982,
#      'percent_change_30d': 6.09841356,
#      'percent_change_60d': 10.21968691,
#      'percent_change_90d': 18.97649616,
#      'market_cap': 8774644306.580523,
#      'market_cap_dominance': 0.3175,
#      'fully_diluted_market_cap': 18125140031.09,
#      'market_cap_by_total_supply': 18125138520.222656,
#      'last_updated': '2021-11-07T15:28:06.000Z'}}},
#   '1027': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 4536,
#    'tags': ['mineable',
#     'pow',
#     'smart-contracts',
#     'ethereum',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'arrington-xrp-capital',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures',
#     'hashkey-capital-portfolio',
#     'kinetic-capital',
#     'huobi-capital',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-xzy-screener'],
#    'max_supply': None,
#    'circulating_supply': 118245601.999,
#    'total_supply': 118245601.999,
#    'platform': None,
#    'cmc_rank': 2,
#    'last_updated': '2021-11-07T15:28:02.000Z',
#    'quote': {'USD': {'price': 4586.983932402437,
#      'volume_24h': 13827014231.744717,
#      'volume_change_24h': -4.7026,
#      'percent_change_1h': -0.62707491,
#      'percent_change_24h': 4.18173898,
#      'percent_change_7d': 8.58814849,
#      'percent_change_30d': 26.03113918,
#      'percent_change_60d': 34.24090502,
#      'percent_change_90d': 46.17113731,
#      'market_cap': 542390676446.66644,
#      'market_cap_dominance': 19.6277,
#      'fully_diluted_market_cap': 542390676446.67,
#      'market_cap_by_total_supply': 542390676446.66644,
#      'last_updated': '2021-11-07T15:28:02.000Z'}}},
#   '1321': {'id': 1321,
#    'name': 'Ethereum Classic',
#    'symbol': 'ETC',
#    'slug': 'ethereum-classic',
#    'num_market_pairs': 256,
#    'tags': ['mineable',
#     'pow',
#     'ethash',
#     'platform',
#     'smart-contracts',
#     'binance-smart-chain',
#     'dcg-portfolio'],
#    'max_supply': 210700000,
#    'circulating_supply': 130835411.09308541,
#    'total_supply': 210700000,
#    'platform': None,
#    'cmc_rank': 33,
#    'last_updated': '2021-11-07T15:28:05.000Z',
#    'quote': {'USD': {'price': 53.70427895455213,
#      'volume_24h': 639024034.6325753,
#      'volume_change_24h': -5.2343,
#      'percent_change_1h': 0.61034732,
#      'percent_change_24h': 2.58348055,
#      'percent_change_7d': -0.39882277,
#      'percent_change_30d': -1.91211348,
#      'percent_change_60d': -8.07127557,
#      'percent_change_90d': -9.84385366,
#      'market_cap': 7026421414.476563,
#      'market_cap_dominance': 0.2543,
#      'fully_diluted_market_cap': 11315491575.72,
#      'market_cap_by_total_supply': 11315491575.724134,
#      'last_updated': '2021-11-07T15:28:05.000Z'}}},
#   '1376': {'id': 1376,
#    'name': 'Neo',
#    'symbol': 'NEO',
#    'slug': 'neo',
#    'num_market_pairs': 227,
#    'tags': ['platform', 'enterprise-solutions', 'smart-contracts'],
#    'max_supply': 100000000,
#    'circulating_supply': 70538831,
#    'total_supply': 100000000,
#    'platform': None,
#    'cmc_rank': 55,
#    'last_updated': '2021-11-07T15:28:05.000Z',
#    'quote': {'USD': {'price': 45.44244674039614,
#      'volume_24h': 224847084.24344754,
#      'volume_change_24h': -17.704,
#      'percent_change_1h': -0.11704558,
#      'percent_change_24h': 3.28783034,
#      'percent_change_7d': 2.41712334,
#      'percent_change_30d': -3.2849244,
#      'percent_change_60d': -6.11944535,
#      'percent_change_90d': -2.54850027,
#      'market_cap': 3205457070.8473043,
#      'market_cap_dominance': 0.116,
#      'fully_diluted_market_cap': 4544244674.04,
#      'market_cap_by_total_supply': 4544244674.039615,
#      'last_updated': '2021-11-07T15:28:05.000Z'}}},
#   '1437': {'id': 1437,
#    'name': 'Zcash',
#    'symbol': 'ZEC',
#    'slug': 'zcash',
#    'num_market_pairs': 224,
#    'tags': ['mineable',
#     'pow',
#     'equihash',
#     'medium-of-exchange',
#     'privacy',
#     'zero-knowledge-proofs',
#     'binance-chain',
#     'binance-smart-chain',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'electric-capital-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'winklevoss-capital',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio'],
#    'max_supply': 21000000,
#    'circulating_supply': 13035056.25,
#    'total_supply': 13035056.25,
#    'platform': None,
#    'cmc_rank': 73,
#    'last_updated': '2021-11-07T15:28:06.000Z',
#    'quote': {'USD': {'price': 161.01367423184772,
#      'volume_24h': 169170717.2794954,
#      'volume_change_24h': -26.3383,
#      'percent_change_1h': -0.03438796,
#      'percent_change_24h': 1.32210043,
#      'percent_change_7d': -8.94880819,
#      'percent_change_30d': 27.65575475,
#      'percent_change_60d': 17.93070666,
#      'percent_change_90d': 22.09341522,
#      'market_cap': 2098822300.6313105,
#      'market_cap_dominance': 0.0759,
#      'fully_diluted_market_cap': 3381287158.87,
#      'market_cap_by_total_supply': 2098822300.6313105,
#      'last_updated': '2021-11-07T15:28:06.000Z'}}},
#   '1518': {'id': 1518,
#    'name': 'Maker',
#    'symbol': 'MKR',
#    'slug': 'maker',
#    'num_market_pairs': 202,
#    'tags': ['store-of-value',
#     'defi',
#     'dao',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'governance',
#     'lending-borowing',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'paradigm-xzy-screener',
#     'near-protocol-ecosystem'],
#    'max_supply': 1005577,
#    'circulating_supply': 991328.38195493,
#    'total_supply': 991328.38195493,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2'},
#    'cmc_rank': 59,
#    'last_updated': '2021-11-07T15:28:06.000Z',
#    'quote': {'USD': {'price': 2950.156216158147,
#      'volume_24h': 159144581.89747536,
#      'volume_change_24h': 22.6778,
#      'percent_change_1h': -0.48150986,
#      'percent_change_24h': 2.57411836,
#      'percent_change_7d': 23.79096919,
#      'percent_change_30d': 14.97865504,
#      'percent_change_60d': -1.03870297,
#      'percent_change_90d': -12.19696559,
#      'market_cap': 2924573588.2783346,
#      'market_cap_dominance': 0.1058,
#      'fully_diluted_market_cap': 2966609237.38,
#      'market_cap_by_total_supply': 2924573588.2783346,
#      'last_updated': '2021-11-07T15:28:06.000Z'}}},
#   '1697': {'id': 1697,
#    'name': 'Basic Attention Token',
#    'symbol': 'BAT',
#    'slug': 'basic-attention-token',
#    'num_market_pairs': 251,
#    'tags': ['marketing',
#     'content-creation',
#     'defi',
#     'payments',
#     'binance-smart-chain',
#     'dcg-portfolio',
#     '1confirmation-portfolio',
#     'pantera-capital-portfolio'],
#    'max_supply': 1500000000,
#    'circulating_supply': 1491852436.4473505,
#    'total_supply': 1500000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0d8775f648430679a709e98d2b0cb6250d2887ef'},
#    'cmc_rank': 85,
#    'last_updated': '2021-11-07T15:28:08.000Z',
#    'quote': {'USD': {'price': 0.99553620470272,
#      'volume_24h': 200029698.76512423,
#      'volume_change_24h': -26.9457,
#      'percent_change_1h': -0.89223997,
#      'percent_change_24h': -0.92286329,
#      'percent_change_7d': 1.5030313,
#      'percent_change_30d': 32.42831616,
#      'percent_change_60d': 31.53564946,
#      'percent_change_90d': 42.68827431,
#      'market_cap': 1485193112.557301,
#      'market_cap_dominance': 0.0537,
#      'fully_diluted_market_cap': 1493304307.05,
#      'market_cap_by_total_supply': 1493304307.05408,
#      'last_updated': '2021-11-07T15:28:08.000Z'}}},
#   '1720': {'id': 1720,
#    'name': 'IOTA',
#    'symbol': 'MIOTA',
#    'slug': 'iota',
#    'num_market_pairs': 61,
#    'tags': ['dag',
#     'medium-of-exchange',
#     'iot',
#     'sharing-economy',
#     'binance-smart-chain'],
#    'max_supply': 2779530283,
#    'circulating_supply': 2779530283,
#    'total_supply': 2779530283,
#    'platform': None,
#    'cmc_rank': 50,
#    'last_updated': '2021-11-07T15:28:08.000Z',
#    'quote': {'USD': {'price': 1.34745454363966,
#      'volume_24h': 38987685.80473635,
#      'volume_change_24h': -45.6277,
#      'percent_change_1h': 0.54014134,
#      'percent_change_24h': 1.84357927,
#      'percent_change_7d': -8.15115268,
#      'percent_change_30d': 0.70045386,
#      'percent_change_60d': -12.69457534,
#      'percent_change_90d': 46.32270665,
#      'market_cap': 3745290709.01238,
#      'market_cap_dominance': 0.1355,
#      'fully_diluted_market_cap': 3745290709.01,
#      'market_cap_by_total_supply': 3745290709.01238,
#      'last_updated': '2021-11-07T15:28:08.000Z'}}},
#   '1765': {'id': 1765,
#    'name': 'EOS',
#    'symbol': 'EOS',
#    'slug': 'eos',
#    'num_market_pairs': 388,
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'smart-contracts',
#     'binance-chain',
#     'binance-smart-chain',
#     'fenbushi-capital-portfolio',
#     'galaxy-digital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 962683016.946,
#    'total_supply': 1038683428.8178,
#    'platform': None,
#    'cmc_rank': 45,
#    'last_updated': '2021-11-07T15:28:08.000Z',
#    'quote': {'USD': {'price': 4.47600884817608,
#      'volume_24h': 644618869.8020774,
#      'volume_change_24h': -24.7171,
#      'percent_change_1h': -0.49551722,
#      'percent_change_24h': 1.33927124,
#      'percent_change_7d': -2.08795477,
#      'percent_change_30d': -5.72045301,
#      'percent_change_60d': -5.4348062,
#      'percent_change_90d': -1.35180648,
#      'market_cap': 4308977701.839139,
#      'market_cap_dominance': 0.1559,
#      'fully_diluted_market_cap': 4649156217.84,
#      'market_cap_by_total_supply': 4649156217.842342,
#      'last_updated': '2021-11-07T15:28:08.000Z'}}},
#   '1831': {'id': 1831,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'slug': 'bitcoin-cash',
#    'num_market_pairs': 526,
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'marketplace',
#     'medium-of-exchange',
#     'store-of-value',
#     'enterprise-solutions',
#     'payments',
#     'binance-chain',
#     'binance-smart-chain'],
#    'max_supply': 21000000,
#    'circulating_supply': 18893781.25,
#    'total_supply': 18893781.25,
#    'platform': None,
#    'cmc_rank': 21,
#    'last_updated': '2021-11-07T15:27:08.000Z',
#    'quote': {'USD': {'price': 595.0901555697407,
#      'volume_24h': 872898935.6515948,
#      'volume_change_24h': -18.9712,
#      'percent_change_1h': 0.09551454,
#      'percent_change_24h': 1.83392412,
#      'percent_change_7d': 0.54128417,
#      'percent_change_30d': -1.81273097,
#      'percent_change_60d': -10.04012752,
#      'percent_change_90d': 0.71082601,
#      'market_cap': 11243503223.36315,
#      'market_cap_dominance': 0.4069,
#      'fully_diluted_market_cap': 12496893266.96,
#      'market_cap_by_total_supply': 11243503223.36315,
#      'last_updated': '2021-11-07T15:27:08.000Z'}}},
#   '1839': {'id': 1839,
#    'name': 'Binance Coin',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'num_market_pairs': 549,
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'payments',
#     'smart-contracts',
#     'binance-smart-chain',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio'],
#    'max_supply': 166801148,
#    'circulating_supply': 166801148,
#    'total_supply': 166801148,
#    'platform': None,
#    'cmc_rank': 3,
#    'last_updated': '2021-11-07T15:27:20.000Z',
#    'quote': {'USD': {'price': 659.6447706329394,
#      'volume_24h': 3065765690.228748,
#      'volume_change_24h': 4.3949,
#      'percent_change_1h': -1.15530461,
#      'percent_change_24h': 7.65523879,
#      'percent_change_7d': 27.81839637,
#      'percent_change_30d': 55.29674682,
#      'percent_change_60d': 59.4362282,
#      'percent_change_90d': 85.84094138,
#      'market_cap': 110029505013.77098,
#      'market_cap_dominance': 3.9817,
#      'fully_diluted_market_cap': 110029505013.77,
#      'market_cap_by_total_supply': 110029505013.77098,
#      'last_updated': '2021-11-07T15:27:20.000Z'}}},
#   '1958': {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'num_market_pairs': 489,
#    'tags': ['media', 'payments', 'binance-smart-chain'],
#    'max_supply': None,
#    'circulating_supply': 71659657369.49,
#    'total_supply': 100850743811.662,
#    'platform': None,
#    'cmc_rank': 30,
#    'last_updated': '2021-11-07T15:27:21.000Z',
#    'quote': {'USD': {'price': 0.1037613761629,
#      'volume_24h': 1649120765.1651125,
#      'volume_change_24h': -2.1475,
#      'percent_change_1h': -0.22019774,
#      'percent_change_24h': 2.21895534,
#      'percent_change_7d': 3.7081211,
#      'percent_change_30d': 5.38686657,
#      'percent_change_60d': 10.7280235,
#      'percent_change_90d': 40.10192851,
#      'market_cap': 7435504664.020182,
#      'market_cap_dominance': 0.2691,
#      'fully_diluted_market_cap': 10464411964.95,
#      'market_cap_by_total_supply': 10464411964.95012,
#      'last_updated': '2021-11-07T15:27:21.000Z'}}},
#   '1966': {'id': 1966,
#    'name': 'Decentraland',
#    'symbol': 'MANA',
#    'slug': 'decentraland',
#    'num_market_pairs': 179,
#    'tags': ['platform',
#     'collectibles-nfts',
#     'gaming',
#     'payments',
#     'metaverse',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'fabric-ventures-portfolio',
#     'kinetic-capital',
#     'polygon-ecosystem',
#     'play-to-earn'],
#    'max_supply': None,
#    'circulating_supply': 1816930691.4950888,
#    'total_supply': 2194010927.320146,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942'},
#    'cmc_rank': 40,
#    'last_updated': '2021-11-07T15:27:20.000Z',
#    'quote': {'USD': {'price': 2.84948691110902,
#      'volume_24h': 1706908637.8776314,
#      'volume_change_24h': -59.4266,
#      'percent_change_1h': -0.54901175,
#      'percent_change_24h': -2.69338285,
#      'percent_change_7d': 4.18768007,
#      'percent_change_30d': 254.67054326,
#      'percent_change_60d': 234.14693318,
#      'percent_change_90d': 276.4606843,
#      'market_cap': 5177320223.807516,
#      'market_cap_dominance': 0.1874,
#      'fully_diluted_market_cap': 6251805420.23,
#      'market_cap_by_total_supply': 6251805420.22892,
#      'last_updated': '2021-11-07T15:27:20.000Z'}}},
#   '1975': {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 477,
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'substrate',
#     'polkadot',
#     'binance-smart-chain',
#     'polkadot-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'near-protocol-ecosystem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 464009553.9174637,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'cmc_rank': 15,
#    'last_updated': '2021-11-07T15:27:20.000Z',
#    'quote': {'USD': {'price': 32.12744064857585,
#      'volume_24h': 736443903.3411272,
#      'volume_change_24h': -39.1795,
#      'percent_change_1h': -0.63722924,
#      'percent_change_24h': 2.30124621,
#      'percent_change_7d': 8.95821313,
#      'percent_change_30d': 18.20284974,
#      'percent_change_60d': 17.98793676,
#      'percent_change_90d': 31.39231128,
#      'market_cap': 14907439403.85547,
#      'market_cap_dominance': 0.5395,
#      'fully_diluted_market_cap': 32127440648.58,
#      'market_cap_by_total_supply': 32127440648.575848,
#      'last_updated': '2021-11-07T15:27:20.000Z'}}},
#   '2010': {'id': 2010,
#    'name': 'Cardano',
#    'symbol': 'ADA',
#    'slug': 'cardano',
#    'num_market_pairs': 305,
#    'tags': ['mineable',
#     'dpos',
#     'pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'staking',
#     'binance-smart-chain',
#     'cardano-ecosystem'],
#    'max_supply': 45000000000,
#    'circulating_supply': 33284656803.355,
#    'total_supply': 33697893006.831,
#    'platform': None,
#    'cmc_rank': 6,
#    'last_updated': '2021-11-07T15:27:22.000Z',
#    'quote': {'USD': {'price': 2.01385965982611,
#      'volume_24h': 1769124087.4717484,
#      'volume_change_24h': -11.1041,
#      'percent_change_1h': 0.65349704,
#      'percent_change_24h': 1.93707285,
#      'percent_change_7d': 2.98552819,
#      'percent_change_30d': -11.62940166,
#      'percent_change_60d': -16.61704344,
#      'percent_change_90d': 36.12522582,
#      'market_cap': 67030627627.43331,
#      'market_cap_dominance': 2.4258,
#      'fully_diluted_market_cap': 90623684692.18,
#      'market_cap_by_total_supply': 67862827347.59332,
#      'last_updated': '2021-11-07T15:27:22.000Z'}}},
#   '2011': {'id': 2011,
#    'name': 'Tezos',
#    'symbol': 'XTZ',
#    'slug': 'tezos',
#    'num_market_pairs': 173,
#    'tags': ['pos',
#     'platform',
#     'enterprise-solutions',
#     'collectibles-nfts',
#     'defi',
#     'smart-contracts',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'boostvc-portfolio',
#     'winklevoss-capital'],
#    'max_supply': None,
#    'circulating_supply': 866023219.960503,
#    'total_supply': 895027882.509527,
#    'platform': None,
#    'cmc_rank': 38,
#    'last_updated': '2021-11-07T15:27:19.000Z',
#    'quote': {'USD': {'price': 6.34930506249579,
#      'volume_24h': 150504642.4931643,
#      'volume_change_24h': -45.5348,
#      'percent_change_1h': -0.30511031,
#      'percent_change_24h': -0.57642461,
#      'percent_change_7d': 0.39707985,
#      'percent_change_30d': -15.05666012,
#      'percent_change_60d': 46.80023622,
#      'percent_change_90d': 90.95932786,
#      'market_cap': 5498645614.734127,
#      'market_cap_dominance': 0.199,
#      'fully_diluted_market_cap': 5682805065.49,
#      'market_cap_by_total_supply': 5682805065.492627,
#      'last_updated': '2021-11-07T15:27:19.000Z'}}},
#   '2130': {'id': 2130,
#    'name': 'Enjin Coin',
#    'symbol': 'ENJ',
#    'slug': 'enjin-coin',
#    'num_market_pairs': 181,
#    'tags': ['media', 'collectibles-nfts', 'gaming', 'ethereum', 'metaverse'],
#    'max_supply': 1000000000,
#    'circulating_supply': 834340659.567558,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'},
#    'cmc_rank': 62,
#    'last_updated': '2021-11-07T15:28:03.000Z',
#    'quote': {'USD': {'price': 3.29351248593353,
#      'volume_24h': 987214377.6822529,
#      'volume_change_24h': -30.3838,
#      'percent_change_1h': -0.06208121,
#      'percent_change_24h': -0.73345404,
#      'percent_change_7d': 30.92150446,
#      'percent_change_30d': 92.48886055,
#      'percent_change_60d': 95.4567592,
#      'percent_change_90d': 112.79473333,
#      'market_cap': 2747911379.8077693,
#      'market_cap_dominance': 0.0994,
#      'fully_diluted_market_cap': 3293512485.93,
#      'market_cap_by_total_supply': 3293512485.93353,
#      'last_updated': '2021-11-07T15:28:03.000Z'}}},
#   '2280': {'id': 2280,
#    'name': 'Filecoin',
#    'symbol': 'FIL',
#    'slug': 'filecoin',
#    'num_market_pairs': 148,
#    'tags': ['mineable',
#     'distributed-computing',
#     'filesharing',
#     'storage',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'hashkey-capital-portfolio',
#     'a16z-portfolio',
#     'winklevoss-capital',
#     'pantera-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 120719294,
#    'total_supply': 120719294,
#    'platform': None,
#    'cmc_rank': 29,
#    'last_updated': '2021-11-07T15:28:04.000Z',
#    'quote': {'USD': {'price': 61.89747956185272,
#      'volume_24h': 467247890.21422005,
#      'volume_change_24h': -41.7198,
#      'percent_change_1h': -0.09385487,
#      'percent_change_24h': 1.79634133,
#      'percent_change_7d': -2.80972059,
#      'percent_change_30d': -19.88333041,
#      'percent_change_60d': -27.51850118,
#      'percent_change_90d': -8.70202827,
#      'market_cap': 7472220033.086289,
#      'market_cap_dominance': 0.2704,
#      'fully_diluted_market_cap': 7472220033.09,
#      'market_cap_by_total_supply': 7472220033.086289,
#      'last_updated': '2021-11-07T15:28:04.000Z'}}},
#   '3180': {'id': 3180,
#    'name': 'Compound Coin',
#    'symbol': 'COMP',
#    'slug': 'compound-coin',
#    'num_market_pairs': 1,
#    'tags': ['mineable'],
#    'max_supply': None,
#    'circulating_supply': 53731717830.4423,
#    'total_supply': 54281727831.4423,
#    'platform': None,
#    'cmc_rank': 2684,
#    'last_updated': '2021-11-07T15:28:03.000Z',
#    'quote': {'USD': {'price': 8.466361e-08,
#      'volume_24h': 170.21443842,
#      'volume_change_24h': -89.1643,
#      'percent_change_1h': -0.34551302,
#      'percent_change_24h': -6.02250266,
#      'percent_change_7d': -9.56475807,
#      'percent_change_30d': -25.52186509,
#      'percent_change_60d': -63.90979247,
#      'percent_change_90d': -74.61401787,
#      'market_cap': 4549.121203026612,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 4595.69,
#      'market_cap_by_total_supply': 4595.687035247376,
#      'last_updated': '2021-11-07T15:28:03.000Z'}}},
#   '3794': {'id': 3794,
#    'name': 'Cosmos',
#    'symbol': 'ATOM',
#    'slug': 'cosmos',
#    'num_market_pairs': 185,
#    'tags': ['platform',
#     'cosmos-ecosystem',
#     'content-creation',
#     'interoperability',
#     'binance-chain',
#     'binance-smart-chain',
#     'polychain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'hashkey-capital-portfolio',
#     '1confirmation-portfolio',
#     'paradigm-xzy-screener',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 224171401.766288,
#    'total_supply': 281956004.766288,
#    'platform': None,
#    'cmc_rank': 27,
#    'last_updated': '2021-11-07T15:28:08.000Z',
#    'quote': {'USD': {'price': 35.8116188564261,
#      'volume_24h': 332224440.51572114,
#      'volume_change_24h': -27.5961,
#      'percent_change_1h': -0.13966908,
#      'percent_change_24h': 1.09472145,
#      'percent_change_7d': -2.07498914,
#      'percent_change_30d': -1.52902482,
#      'percent_change_60d': 74.71534611,
#      'percent_change_90d': 157.70733495,
#      'market_cap': 8027940798.565071,
#      'market_cap_dominance': 0.2905,
#      'fully_diluted_market_cap': 10097300976.97,
#      'market_cap_by_total_supply': 10097300976.970966,
#      'last_updated': '2021-11-07T15:28:08.000Z'}}},
#   '3890': {'id': 3890,
#    'name': 'Polygon',
#    'symbol': 'MATIC',
#    'slug': 'polygon',
#    'num_market_pairs': 250,
#    'tags': ['platform',
#     'enterprise-solutions',
#     'state-channels',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'polygon-ecosystem'],
#    'max_supply': 10000000000,
#    'circulating_supply': 6822312959.27,
#    'total_supply': 10000000000,
#    'platform': None,
#    'cmc_rank': 19,
#    'last_updated': '2021-11-07T15:27:09.000Z',
#    'quote': {'USD': {'price': 1.9056924113017,
#      'volume_24h': 657963771.9226898,
#      'volume_change_24h': -14.4748,
#      'percent_change_1h': 0.03530846,
#      'percent_change_24h': 2.62334783,
#      'percent_change_7d': 3.36148175,
#      'percent_change_30d': 37.35053825,
#      'percent_change_60d': 46.41919085,
#      'percent_change_90d': 67.13076757,
#      'market_cap': 13001230034.006084,
#      'market_cap_dominance': 0.4705,
#      'fully_diluted_market_cap': 19056924113.02,
#      'market_cap_by_total_supply': 19056924113.017,
#      'last_updated': '2021-11-07T15:27:09.000Z'}}},
#   '4030': {'id': 4030,
#    'name': 'Algorand',
#    'symbol': 'ALGO',
#    'slug': 'algorand',
#    'num_market_pairs': 155,
#    'tags': ['pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'arrington-xrp-capital',
#     'kinetic-capital',
#     'usv-portfolio',
#     'multicoin-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': 10000000000,
#    'circulating_supply': 6230681252.874642,
#    'total_supply': 6691860972.776984,
#    'platform': None,
#    'cmc_rank': 20,
#    'last_updated': '2021-11-07T15:28:08.000Z',
#    'quote': {'USD': {'price': 1.85137030466614,
#      'volume_24h': 176561970.5450802,
#      'volume_change_24h': -20.4879,
#      'percent_change_1h': 0.20837962,
#      'percent_change_24h': 1.6638817,
#      'percent_change_7d': 2.62774514,
#      'percent_change_30d': -6.94189439,
#      'percent_change_60d': 7.36563524,
#      'percent_change_90d': 114.81968058,
#      'market_cap': 11535298249.412134,
#      'market_cap_dominance': 0.4174,
#      'fully_diluted_market_cap': 18513703046.66,
#      'market_cap_by_total_supply': 12389112687.953577,
#      'last_updated': '2021-11-07T15:28:08.000Z'}}},
#   '4307': {'id': 4307,
#    'name': 'UNICORN Token',
#    'symbol': 'UNI',
#    'slug': 'unicorn-token',
#    'num_market_pairs': 1,
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 106912508.514,
#    'total_supply': 9800000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2730d6fdc86c95a74253beffaa8306b40fedecbb'},
#    'cmc_rank': 2635,
#    'last_updated': '2021-11-07T15:28:04.000Z',
#    'quote': {'USD': {'price': 0.00012367528985,
#      'volume_24h': 9.71469402,
#      'volume_change_24h': 1.7363,
#      'percent_change_1h': -0.34177113,
#      'percent_change_24h': 1.73627322,
#      'percent_change_7d': -59.27179347,
#      'percent_change_30d': -54.68402464,
#      'percent_change_60d': -32.96644076,
#      'percent_change_90d': 34.58070351,
#      'market_cap': 13222.435479059543,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 1212017.84,
#      'market_cap_by_total_supply': 1212017.84053,
#      'last_updated': '2021-11-07T15:28:04.000Z'}}},
#   '5426': {'id': 5426,
#    'name': 'Solana',
#    'symbol': 'SOL',
#    'slug': 'solana',
#    'num_market_pairs': 177,
#    'tags': ['pos',
#     'platform',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'kinetic-capital',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 302512708.83442175,
#    'total_supply': 508383748.94538176,
#    'platform': None,
#    'cmc_rank': 4,
#    'last_updated': '2021-11-07T15:28:05.000Z',
#    'quote': {'USD': {'price': 252.24633479247626,
#      'volume_24h': 3291852096.6735134,
#      'volume_change_24h': 3.4074,
#      'percent_change_1h': -0.0148386,
#      'percent_change_24h': 1.02490516,
#      'percent_change_7d': 27.20739175,
#      'percent_change_30d': 51.08777244,
#      'percent_change_60d': 55.67833882,
#      'percent_change_90d': 534.2498653,
#      'market_cap': 76307722031.62643,
#      'market_cap_dominance': 2.7615,
#      'fully_diluted_market_cap': 128237937339.53,
#      'market_cap_by_total_supply': 128237937339.53098,
#      'last_updated': '2021-11-07T15:28:05.000Z'}}},
#   '5692': {'id': 5692,
#    'name': 'Compound',
#    'symbol': 'COMP',
#    'slug': 'compound',
#    'num_market_pairs': 218,
#    'tags': ['defi',
#     'dao',
#     'yield-farming',
#     'binance-smart-chain',
#     'polkadot-ecosystem',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'lending-borowing',
#     'dragonfly-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'paradigm-xzy-screener'],
#    'max_supply': 10000000,
#    'circulating_supply': 6018895.25927744,
#    'total_supply': 10000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xc00e94cb662c3520282e6f5717214004a7f26888'},
#    'cmc_rank': 71,
#    'last_updated': '2021-11-07T15:28:07.000Z',
#    'quote': {'USD': {'price': 360.6041981030181,
#      'volume_24h': 109490434.82304932,
#      'volume_change_24h': -18.43,
#      'percent_change_1h': -0.77026458,
#      'percent_change_24h': 4.74645377,
#      'percent_change_7d': 6.67943823,
#      'percent_change_30d': 8.64355474,
#      'percent_change_60d': -11.47683931,
#      'percent_change_90d': -25.57456656,
#      'market_cap': 2170438898.4377985,
#      'market_cap_dominance': 0.0785,
#      'fully_diluted_market_cap': 3606041981.03,
#      'market_cap_by_total_supply': 3606041981.0301814,
#      'last_updated': '2021-11-07T15:28:07.000Z'}}},
#   '5711': {'id': 5711,
#    'name': 'Golden Ratio Token',
#    'symbol': 'GRT',
#    'slug': 'golden-ratio-token',
#    'num_market_pairs': 7,
#    'tags': [],
#    'max_supply': None,
#    'circulating_supply': 0,
#    'total_supply': 16180,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xb83cd8d39462b761bb0092437d38b37812dd80a2'},
#    'cmc_rank': 3033,
#    'last_updated': '2021-11-07T15:28:07.000Z',
#    'quote': {'USD': {'price': 1.06520507595911,
#      'volume_24h': 1661904.6878614,
#      'volume_change_24h': -47.376,
#      'percent_change_1h': 0.221093,
#      'percent_change_24h': 3.22414323,
#      'percent_change_7d': 16.17333081,
#      'percent_change_30d': 46.18072265,
#      'percent_change_60d': 32.02236538,
#      'percent_change_90d': 50.62234762,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 17235.02,
#      'market_cap_by_total_supply': 17235.0181290184,
#      'last_updated': '2021-11-07T15:28:07.000Z'}}},
#   '5864': {'id': 5864,
#    'name': 'yearn.finance',
#    'symbol': 'YFI',
#    'slug': 'yearn-finance',
#    'num_market_pairs': 209,
#    'tags': ['defi',
#     'yield-farming',
#     'binance-smart-chain',
#     'yield-aggregator',
#     'yearn-partnerships',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'framework-ventures',
#     'alameda-research-portfolio',
#     'parafi-capital',
#     'fantom-ecosystem'],
#    'max_supply': 36666,
#    'circulating_supply': 36637.72122588,
#    'total_supply': 36666,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e'},
#    'cmc_rank': 94,
#    'last_updated': '2021-11-07T15:28:08.000Z',
#    'quote': {'USD': {'price': 34249.03811344374,
#      'volume_24h': 111208968.94982041,
#      'volume_change_24h': -1.3423,
#      'percent_change_1h': -0.39561172,
#      'percent_change_24h': 4.0303183,
#      'percent_change_7d': 1.73197757,
#      'percent_change_30d': -5.26908882,
#      'percent_change_60d': -1.47559,
#      'percent_change_90d': 1.0078872,
#      'market_cap': 1254806710.6548908,
#      'market_cap_dominance': 0.0454,
#      'fully_diluted_market_cap': 1255775231.47,
#      'market_cap_by_total_supply': 1255775231.467528,
#      'last_updated': '2021-11-07T15:28:08.000Z'}}},
#   '6538': {'id': 6538,
#    'name': 'Curve DAO Token',
#    'symbol': 'CRV',
#    'slug': 'curve-dao-token',
#    'num_market_pairs': 166,
#    'tags': ['decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'governance',
#     'framework-ventures',
#     'alameda-research-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem'],
#    'max_supply': 3303030299,
#    'circulating_supply': 413487283.14591277,
#    'total_supply': 1618756965.7925403,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xD533a949740bb3306d119CC777fa900bA034cd52'},
#    'cmc_rank': 77,
#    'last_updated': '2021-11-07T15:28:05.000Z',
#    'quote': {'USD': {'price': 4.36173042350267,
#      'volume_24h': 278195315.82953036,
#      'volume_change_24h': -4.3355,
#      'percent_change_1h': 1.46528708,
#      'percent_change_24h': 8.95180404,
#      'percent_change_7d': -1.86957612,
#      'percent_change_30d': 54.22430817,
#      'percent_change_60d': 123.29631175,
#      'percent_change_90d': 132.05013434,
#      'market_cap': 1803520062.6289904,
#      'market_cap_dominance': 0.0653,
#      'fully_diluted_market_cap': 14406927744.9,
#      'market_cap_by_total_supply': 7060581505.954194,
#      'last_updated': '2021-11-07T15:28:05.000Z'}}},
#   '6636': {'id': 6636,
#    'name': 'Polkadot',
#    'symbol': 'DOT',
#    'slug': 'polkadot-new',
#    'num_market_pairs': 242,
#    'tags': ['substrate',
#     'polkadot',
#     'binance-chain',
#     'binance-smart-chain',
#     'polkadot-ecosystem',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'coinfund-portfolio',
#     'fabric-ventures-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kinetic-capital',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 987579314.957085,
#    'total_supply': 1103303471.382273,
#    'platform': None,
#    'cmc_rank': 8,
#    'last_updated': '2021-11-07T15:28:06.000Z',
#    'quote': {'USD': {'price': 53.06767502840045,
#      'volume_24h': 1548802337.8312247,
#      'volume_change_24h': -12.2066,
#      'percent_change_1h': -0.66698318,
#      'percent_change_24h': 4.73129273,
#      'percent_change_7d': 25.61895915,
#      'percent_change_30d': 56.76053359,
#      'percent_change_60d': 89.30892413,
#      'percent_change_90d': 155.09210318,
#      'market_cap': 52408538150.912926,
#      'market_cap_dominance': 1.8957,
#      'fully_diluted_market_cap': 58549750077.02,
#      'market_cap_by_total_supply': 58549750077.02058,
#      'last_updated': '2021-11-07T15:28:06.000Z'}}},
#   '6719': {'id': 6719,
#    'name': 'The Graph',
#    'symbol': 'GRT',
#    'slug': 'the-graph',
#    'num_market_pairs': 135,
#    'tags': ['ai-big-data',
#     'enterprise-solutions',
#     'defi',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'solana-ecosystem',
#     'analytics',
#     'coinfund-portfolio',
#     'dcg-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures',
#     'ledgerprime-portfolio',
#     'multicoin-capital-portfolio',
#     'parafi-capital',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'near-protocol-ecosystem'],
#    'max_supply': 10057044431,
#    'circulating_supply': 4715735200,
#    'total_supply': 10000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#    'cmc_rank': 41,
#    'last_updated': '2021-11-07T15:28:07.000Z',
#    'quote': {'USD': {'price': 1.06387277375895,
#      'volume_24h': 158835660.1217478,
#      'volume_change_24h': -36.7535,
#      'percent_change_1h': 0.09938425,
#      'percent_change_24h': 2.9257521,
#      'percent_change_7d': 15.01266501,
#      'percent_change_30d': 45.91347925,
#      'percent_change_60d': 31.81811882,
#      'percent_change_90d': 50.10333387,
#      'market_cap': 5016942287.536716,
#      'market_cap_dominance': 0.1816,
#      'fully_diluted_market_cap': 10699415754.63,
#      'market_cap_by_total_supply': 10638727737.5895,
#      'last_updated': '2021-11-07T15:28:07.000Z'}}},
#   '7083': {'id': 7083,
#    'name': 'Uniswap',
#    'symbol': 'UNI',
#    'slug': 'uniswap',
#    'num_market_pairs': 283,
#    'tags': ['decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'binance-smart-chain',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'defiance-capital',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-xzy-screener',
#     'arbitrum-ecosytem'],
#    'max_supply': 1000000000,
#    'circulating_supply': 627596088.553873,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'cmc_rank': 14,
#    'last_updated': '2021-11-07T15:27:21.000Z',
#    'quote': {'USD': {'price': 25.18920908269433,
#      'volume_24h': 173213365.68081266,
#      'volume_change_24h': -33.7431,
#      'percent_change_1h': -0.64655852,
#      'percent_change_24h': 1.10196341,
#      'percent_change_7d': 2.6413126,
#      'percent_change_30d': -2.42174226,
#      'percent_change_60d': 8.39331714,
#      'percent_change_90d': -10.86479358,
#      'market_cap': 15808649094.064651,
#      'market_cap_dominance': 0.5718,
#      'fully_diluted_market_cap': 25189209082.69,
#      'market_cap_by_total_supply': 25189209082.69433,
#      'last_updated': '2021-11-07T15:27:21.000Z'}}},
#   '7278': {'id': 7278,
#    'name': 'Aave',
#    'symbol': 'AAVE',
#    'slug': 'aave',
#    'num_market_pairs': 249,
#    'tags': ['defi',
#     'dao',
#     'yield-farming',
#     'binance-smart-chain',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'lending-borowing',
#     'blockchain-capital-portfolio',
#     'defiance-capital',
#     'framework-ventures',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'polygon-ecosystem',
#     'fantom-ecosystem'],
#    'max_supply': 16000000,
#    'circulating_supply': 13243463.31760031,
#    'total_supply': 16000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x7Fc66500c84A76Ad7e9c93437bFc5Ac33E2DDaE9'},
#    'cmc_rank': 46,
#    'last_updated': '2021-11-07T15:28:03.000Z',
#    'quote': {'USD': {'price': 321.4572935384642,
#      'volume_24h': 203176558.822497,
#      'volume_change_24h': -28.3634,
#      'percent_change_1h': -0.14707462,
#      'percent_change_24h': 2.35927452,
#      'percent_change_7d': 3.95655872,
#      'percent_change_30d': 0.3008365,
#      'percent_change_60d': -4.3273747,
#      'percent_change_90d': -15.31225915,
#      'market_cap': 4257207875.1517262,
#      'market_cap_dominance': 0.154,
#      'fully_diluted_market_cap': 5143316696.62,
#      'market_cap_by_total_supply': 5143316696.615428,
#      'last_updated': '2021-11-07T15:28:03.000Z'}}},
#   '8104': {'id': 8104,
#    'name': '1inch Network',
#    'symbol': '1INCH',
#    'slug': '1inch',
#    'num_market_pairs': 145,
#    'tags': ['decentralized-exchange',
#     'defi',
#     'amm',
#     'binance-smart-chain',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'alameda-research-portfolio',
#     'parafi-capital'],
#    'max_supply': None,
#    'circulating_supply': 180362122.33131585,
#    'total_supply': 1500000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x111111111117dc0aa78b770fa6a738034120c302'},
#    'cmc_rank': 123,
#    'last_updated': '2021-11-07T15:27:21.000Z',
#    'quote': {'USD': {'price': 4.55702502755284,
#      'volume_24h': 162352221.5140035,
#      'volume_change_24h': 2.272,
#      'percent_change_1h': 0.2228994,
#      'percent_change_24h': 5.51696851,
#      'percent_change_7d': 1.913526,
#      'percent_change_30d': 40.99621648,
#      'percent_change_60d': 57.96385305,
#      'percent_change_90d': 70.01750505,
#      'market_cap': 821914705.4863534,
#      'market_cap_dominance': 0.0297,
#      'fully_diluted_market_cap': 6835537541.33,
#      'market_cap_by_total_supply': 6835537541.329261,
#      'last_updated': '2021-11-07T15:27:21.000Z'}}},
#   '12003': {'id': 12003,
#    'name': 'SOL RUNE - Rune.Game',
#    'symbol': 'SOL',
#    'slug': 'sol-rune---rune-game',
#    'num_market_pairs': 2,
#    'tags': [],
#    'max_supply': 118852,
#    'circulating_supply': 0,
#    'total_supply': 0,
#    'platform': {'id': 1839,
#     'name': 'Binance Smart Chain (BEP20)',
#     'symbol': 'BNB',
#     'slug': 'binance-coin',
#     'token_address': '0x4ffd3b8ba90f5430cda7f4cc4c0a80df3cd0e495'},
#    'cmc_rank': 5702,
#    'last_updated': '2021-11-07T15:27:12.000Z',
#    'quote': {'USD': {'price': 1.27502381897576,
#      'volume_24h': 1242.4142615,
#      'volume_change_24h': 80.9086,
#      'percent_change_1h': -0.87634215,
#      'percent_change_24h': -2.860976,
#      'percent_change_7d': 27.32476126,
#      'percent_change_30d': 32.41233109,
#      'percent_change_60d': 17.66580704,
#      'percent_change_90d': 17.66580704,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 151539.13,
#      'market_cap_by_total_supply': 0,
#      'last_updated': '2021-11-07T15:27:12.000Z'}}},
#   '12712': {'id': 12712,
#    'name': 'Genesis Mana',
#    'symbol': 'MANA',
#    'slug': 'genesis-mana',
#    'num_market_pairs': 1,
#    'tags': [],
#    'max_supply': 412,
#    'circulating_supply': 0,
#    'total_supply': 412,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2d77f5b3efa51821ad6483adaf38ea4cb1824cc5'},
#    'cmc_rank': 5273,
#    'last_updated': '2021-11-07T15:28:06.000Z',
#    'quote': {'USD': {'price': 1212.2360775481925,
#      'volume_24h': 10382.47958223,
#      'volume_change_24h': -34.9741,
#      'percent_change_1h': -1.2680514,
#      'percent_change_24h': 0.57964011,
#      'percent_change_7d': 2.21677718,
#      'percent_change_30d': -26.70660743,
#      'percent_change_60d': -26.70660743,
#      'percent_change_90d': -26.70660743,
#      'market_cap': 0,
#      'market_cap_dominance': 0,
#      'fully_diluted_market_cap': 499441.26,
#      'market_cap_by_total_supply': 499441.2639498553,
#      'last_updated': '2021-11-07T15:28:06.000Z'}}}}}

# %% [markdown]
# ### Extract relevant data from coin_quotes

# %%
#get a list of dictionaries
coin_quotes_list = [value for value in coin_quotes["data"].values()]

# %%
coin_quotes_list
len(coin_quotes_list)
# Out:
# 40

# %% [markdown]
# Get list of relevant fields from the dicts

# %%
from operator import itemgetter
temp = [itemgetter("id", "name", "symbol", "quote")(coin_quotes_list[i]) for i in range(len(coin_quotes_list))]
temp
# Out:
# [(1,
#   'Bitcoin',
#   'BTC',
#   {'USD': {'price': 61817.78239076061,
#     'volume_24h': 25038723279.23909,
#     'volume_change_24h': -17.0438,
#     'percent_change_1h': -0.39430395,
#     'percent_change_24h': 1.78396473,
#     'percent_change_7d': 1.77794044,
#     'percent_change_30d': 13.25700736,
#     'percent_change_60d': 34.02405551,
#     'percent_change_90d': 34.53747557,
#     'market_cap': 1166282842399.5542,
#     'market_cap_dominance': 42.204,
#     'fully_diluted_market_cap': 1298173430205.97,
#     'market_cap_by_total_supply': 1166282842399.5542,
#     'last_updated': '2021-11-07T15:28:02.000Z'}}),
#  (2,
#   'Litecoin',
#   'LTC',
#   {'USD': {'price': 199.67508544626386,
#     'volume_24h': 1354702269.6045868,
#     'volume_change_24h': -14.8736,
#     'percent_change_1h': -0.10227462,
#     'percent_change_24h': 2.41245627,
#     'percent_change_7d': 5.14942138,
#     'percent_change_30d': 9.70080173,
#     'percent_change_60d': 10.28473558,
#     'percent_change_90d': 21.87094183,
#     'market_cap': 13761623386.007582,
#     'market_cap_dominance': 0.4978,
#     'fully_diluted_market_cap': 16772707177.49,
#     'market_cap_by_total_supply': 16772707177.486164,
#     'last_updated': '2021-11-07T15:28:02.000Z'}}),
#  (52,
#   'XRP',
#   'XRP',
#   {'USD': {'price': 1.21090065523293,
#     'volume_24h': 2851808586.443647,
#     'volume_change_24h': -6.3259,
#     'percent_change_1h': -0.05903268,
#     'percent_change_24h': 6.33864669,
#     'percent_change_7d': 10.86896344,
#     'percent_change_30d': 12.47919347,
#     'percent_change_60d': 9.98100668,
#     'percent_change_90d': 47.53294577,
#     'market_cap': 57011237096.0785,
#     'market_cap_dominance': 2.0632,
#     'fully_diluted_market_cap': 121090065523.29,
#     'market_cap_by_total_supply': 121078152428.35768,
#     'last_updated': '2021-11-07T15:28:03.000Z'}}),
#  (74,
#   'Dogecoin',
#   'DOGE',
#   {'USD': {'price': 0.26491235740698,
#     'volume_24h': 1102478569.193879,
#     'volume_change_24h': -19.5285,
#     'percent_change_1h': -0.37200893,
#     'percent_change_24h': 2.96309197,
#     'percent_change_7d': 1.86983944,
#     'percent_change_30d': 7.1993224,
#     'percent_change_60d': 6.15064986,
#     'percent_change_90d': 4.05685171,
#     'market_cap': 34971437132.85317,
#     'market_cap_dominance': 1.2656,
#     'fully_diluted_market_cap': 34971437132.85,
#     'market_cap_by_total_supply': 34971437132.85317,
#     'last_updated': '2021-11-07T15:28:03.000Z'}}),
#  (131,
#   'Dash',
#   'DASH',
#   {'USD': {'price': 192.97212111812073,
#     'volume_24h': 191847328.42721605,
#     'volume_change_24h': -17.3986,
#     'percent_change_1h': 0.07101938,
#     'percent_change_24h': 1.88422848,
#     'percent_change_7d': 0.46861214,
#     'percent_change_30d': 0.67632069,
#     'percent_change_60d': -4.20314662,
#     'percent_change_90d': 12.9576597,
#     'market_cap': 2010621126.8396711,
#     'market_cap_dominance': 0.0728,
#     'fully_diluted_market_cap': 3647173089.13,
#     'market_cap_by_total_supply': 2010621126.8396711,
#     'last_updated': '2021-11-07T15:28:03.000Z'}}),
#  (512,
#   'Stellar',
#   'XLM',
#   {'USD': {'price': 0.36248970160691,
#     'volume_24h': 410164026.0481368,
#     'volume_change_24h': -10.243,
#     'percent_change_1h': -0.54581768,
#     'percent_change_24h': 2.73642344,
#     'percent_change_7d': -2.68557982,
#     'percent_change_30d': 6.09841356,
#     'percent_change_60d': 10.21968691,
#     'percent_change_90d': 18.97649616,
#     'market_cap': 8774644306.580523,
#     'market_cap_dominance': 0.3175,
#     'fully_diluted_market_cap': 18125140031.09,
#     'market_cap_by_total_supply': 18125138520.222656,
#     'last_updated': '2021-11-07T15:28:06.000Z'}}),
#  (1027,
#   'Ethereum',
#   'ETH',
#   {'USD': {'price': 4586.983932402437,
#     'volume_24h': 13827014231.744717,
#     'volume_change_24h': -4.7026,
#     'percent_change_1h': -0.62707491,
#     'percent_change_24h': 4.18173898,
#     'percent_change_7d': 8.58814849,
#     'percent_change_30d': 26.03113918,
#     'percent_change_60d': 34.24090502,
#     'percent_change_90d': 46.17113731,
#     'market_cap': 542390676446.66644,
#     'market_cap_dominance': 19.6277,
#     'fully_diluted_market_cap': 542390676446.67,
#     'market_cap_by_total_supply': 542390676446.66644,
#     'last_updated': '2021-11-07T15:28:02.000Z'}}),
#  (1321,
#   'Ethereum Classic',
#   'ETC',
#   {'USD': {'price': 53.70427895455213,
#     'volume_24h': 639024034.6325753,
#     'volume_change_24h': -5.2343,
#     'percent_change_1h': 0.61034732,
#     'percent_change_24h': 2.58348055,
#     'percent_change_7d': -0.39882277,
#     'percent_change_30d': -1.91211348,
#     'percent_change_60d': -8.07127557,
#     'percent_change_90d': -9.84385366,
#     'market_cap': 7026421414.476563,
#     'market_cap_dominance': 0.2543,
#     'fully_diluted_market_cap': 11315491575.72,
#     'market_cap_by_total_supply': 11315491575.724134,
#     'last_updated': '2021-11-07T15:28:05.000Z'}}),
#  (1376,
#   'Neo',
#   'NEO',
#   {'USD': {'price': 45.44244674039614,
#     'volume_24h': 224847084.24344754,
#     'volume_change_24h': -17.704,
#     'percent_change_1h': -0.11704558,
#     'percent_change_24h': 3.28783034,
#     'percent_change_7d': 2.41712334,
#     'percent_change_30d': -3.2849244,
#     'percent_change_60d': -6.11944535,
#     'percent_change_90d': -2.54850027,
#     'market_cap': 3205457070.8473043,
#     'market_cap_dominance': 0.116,
#     'fully_diluted_market_cap': 4544244674.04,
#     'market_cap_by_total_supply': 4544244674.039615,
#     'last_updated': '2021-11-07T15:28:05.000Z'}}),
#  (1437,
#   'Zcash',
#   'ZEC',
#   {'USD': {'price': 161.01367423184772,
#     'volume_24h': 169170717.2794954,
#     'volume_change_24h': -26.3383,
#     'percent_change_1h': -0.03438796,
#     'percent_change_24h': 1.32210043,
#     'percent_change_7d': -8.94880819,
#     'percent_change_30d': 27.65575475,
#     'percent_change_60d': 17.93070666,
#     'percent_change_90d': 22.09341522,
#     'market_cap': 2098822300.6313105,
#     'market_cap_dominance': 0.0759,
#     'fully_diluted_market_cap': 3381287158.87,
#     'market_cap_by_total_supply': 2098822300.6313105,
#     'last_updated': '2021-11-07T15:28:06.000Z'}}),
#  (1518,
#   'Maker',
#   'MKR',
#   {'USD': {'price': 2950.156216158147,
#     'volume_24h': 159144581.89747536,
#     'volume_change_24h': 22.6778,
#     'percent_change_1h': -0.48150986,
#     'percent_change_24h': 2.57411836,
#     'percent_change_7d': 23.79096919,
#     'percent_change_30d': 14.97865504,
#     'percent_change_60d': -1.03870297,
#     'percent_change_90d': -12.19696559,
#     'market_cap': 2924573588.2783346,
#     'market_cap_dominance': 0.1058,
#     'fully_diluted_market_cap': 2966609237.38,
#     'market_cap_by_total_supply': 2924573588.2783346,
#     'last_updated': '2021-11-07T15:28:06.000Z'}}),
#  (1697,
#   'Basic Attention Token',
#   'BAT',
#   {'USD': {'price': 0.99553620470272,
#     'volume_24h': 200029698.76512423,
#     'volume_change_24h': -26.9457,
#     'percent_change_1h': -0.89223997,
#     'percent_change_24h': -0.92286329,
#     'percent_change_7d': 1.5030313,
#     'percent_change_30d': 32.42831616,
#     'percent_change_60d': 31.53564946,
#     'percent_change_90d': 42.68827431,
#     'market_cap': 1485193112.557301,
#     'market_cap_dominance': 0.0537,
#     'fully_diluted_market_cap': 1493304307.05,
#     'market_cap_by_total_supply': 1493304307.05408,
#     'last_updated': '2021-11-07T15:28:08.000Z'}}),
#  (1720,
#   'IOTA',
#   'MIOTA',
#   {'USD': {'price': 1.34745454363966,
#     'volume_24h': 38987685.80473635,
#     'volume_change_24h': -45.6277,
#     'percent_change_1h': 0.54014134,
#     'percent_change_24h': 1.84357927,
#     'percent_change_7d': -8.15115268,
#     'percent_change_30d': 0.70045386,
#     'percent_change_60d': -12.69457534,
#     'percent_change_90d': 46.32270665,
#     'market_cap': 3745290709.01238,
#     'market_cap_dominance': 0.1355,
#     'fully_diluted_market_cap': 3745290709.01,
#     'market_cap_by_total_supply': 3745290709.01238,
#     'last_updated': '2021-11-07T15:28:08.000Z'}}),
#  (1765,
#   'EOS',
#   'EOS',
#   {'USD': {'price': 4.47600884817608,
#     'volume_24h': 644618869.8020774,
#     'volume_change_24h': -24.7171,
#     'percent_change_1h': -0.49551722,
#     'percent_change_24h': 1.33927124,
#     'percent_change_7d': -2.08795477,
#     'percent_change_30d': -5.72045301,
#     'percent_change_60d': -5.4348062,
#     'percent_change_90d': -1.35180648,
#     'market_cap': 4308977701.839139,
#     'market_cap_dominance': 0.1559,
#     'fully_diluted_market_cap': 4649156217.84,
#     'market_cap_by_total_supply': 4649156217.842342,
#     'last_updated': '2021-11-07T15:28:08.000Z'}}),
#  (1831,
#   'Bitcoin Cash',
#   'BCH',
#   {'USD': {'price': 595.0901555697407,
#     'volume_24h': 872898935.6515948,
#     'volume_change_24h': -18.9712,
#     'percent_change_1h': 0.09551454,
#     'percent_change_24h': 1.83392412,
#     'percent_change_7d': 0.54128417,
#     'percent_change_30d': -1.81273097,
#     'percent_change_60d': -10.04012752,
#     'percent_change_90d': 0.71082601,
#     'market_cap': 11243503223.36315,
#     'market_cap_dominance': 0.4069,
#     'fully_diluted_market_cap': 12496893266.96,
#     'market_cap_by_total_supply': 11243503223.36315,
#     'last_updated': '2021-11-07T15:27:08.000Z'}}),
#  (1839,
#   'Binance Coin',
#   'BNB',
#   {'USD': {'price': 659.6447706329394,
#     'volume_24h': 3065765690.228748,
#     'volume_change_24h': 4.3949,
#     'percent_change_1h': -1.15530461,
#     'percent_change_24h': 7.65523879,
#     'percent_change_7d': 27.81839637,
#     'percent_change_30d': 55.29674682,
#     'percent_change_60d': 59.4362282,
#     'percent_change_90d': 85.84094138,
#     'market_cap': 110029505013.77098,
#     'market_cap_dominance': 3.9817,
#     'fully_diluted_market_cap': 110029505013.77,
#     'market_cap_by_total_supply': 110029505013.77098,
#     'last_updated': '2021-11-07T15:27:20.000Z'}}),
#  (1958,
#   'TRON',
#   'TRX',
#   {'USD': {'price': 0.1037613761629,
#     'volume_24h': 1649120765.1651125,
#     'volume_change_24h': -2.1475,
#     'percent_change_1h': -0.22019774,
#     'percent_change_24h': 2.21895534,
#     'percent_change_7d': 3.7081211,
#     'percent_change_30d': 5.38686657,
#     'percent_change_60d': 10.7280235,
#     'percent_change_90d': 40.10192851,
#     'market_cap': 7435504664.020182,
#     'market_cap_dominance': 0.2691,
#     'fully_diluted_market_cap': 10464411964.95,
#     'market_cap_by_total_supply': 10464411964.95012,
#     'last_updated': '2021-11-07T15:27:21.000Z'}}),
#  (1966,
#   'Decentraland',
#   'MANA',
#   {'USD': {'price': 2.84948691110902,
#     'volume_24h': 1706908637.8776314,
#     'volume_change_24h': -59.4266,
#     'percent_change_1h': -0.54901175,
#     'percent_change_24h': -2.69338285,
#     'percent_change_7d': 4.18768007,
#     'percent_change_30d': 254.67054326,
#     'percent_change_60d': 234.14693318,
#     'percent_change_90d': 276.4606843,
#     'market_cap': 5177320223.807516,
#     'market_cap_dominance': 0.1874,
#     'fully_diluted_market_cap': 6251805420.23,
#     'market_cap_by_total_supply': 6251805420.22892,
#     'last_updated': '2021-11-07T15:27:20.000Z'}}),
#  (1975,
#   'Chainlink',
#   'LINK',
#   {'USD': {'price': 32.12744064857585,
#     'volume_24h': 736443903.3411272,
#     'volume_change_24h': -39.1795,
#     'percent_change_1h': -0.63722924,
#     'percent_change_24h': 2.30124621,
#     'percent_change_7d': 8.95821313,
#     'percent_change_30d': 18.20284974,
#     'percent_change_60d': 17.98793676,
#     'percent_change_90d': 31.39231128,
#     'market_cap': 14907439403.85547,
#     'market_cap_dominance': 0.5395,
#     'fully_diluted_market_cap': 32127440648.58,
#     'market_cap_by_total_supply': 32127440648.575848,
#     'last_updated': '2021-11-07T15:27:20.000Z'}}),
#  (2010,
#   'Cardano',
#   'ADA',
#   {'USD': {'price': 2.01385965982611,
#     'volume_24h': 1769124087.4717484,
#     'volume_change_24h': -11.1041,
#     'percent_change_1h': 0.65349704,
#     'percent_change_24h': 1.93707285,
#     'percent_change_7d': 2.98552819,
#     'percent_change_30d': -11.62940166,
#     'percent_change_60d': -16.61704344,
#     'percent_change_90d': 36.12522582,
#     'market_cap': 67030627627.43331,
#     'market_cap_dominance': 2.4258,
#     'fully_diluted_market_cap': 90623684692.18,
#     'market_cap_by_total_supply': 67862827347.59332,
#     'last_updated': '2021-11-07T15:27:22.000Z'}}),
#  (2011,
#   'Tezos',
#   'XTZ',
#   {'USD': {'price': 6.34930506249579,
#     'volume_24h': 150504642.4931643,
#     'volume_change_24h': -45.5348,
#     'percent_change_1h': -0.30511031,
#     'percent_change_24h': -0.57642461,
#     'percent_change_7d': 0.39707985,
#     'percent_change_30d': -15.05666012,
#     'percent_change_60d': 46.80023622,
#     'percent_change_90d': 90.95932786,
#     'market_cap': 5498645614.734127,
#     'market_cap_dominance': 0.199,
#     'fully_diluted_market_cap': 5682805065.49,
#     'market_cap_by_total_supply': 5682805065.492627,
#     'last_updated': '2021-11-07T15:27:19.000Z'}}),
#  (2130,
#   'Enjin Coin',
#   'ENJ',
#   {'USD': {'price': 3.29351248593353,
#     'volume_24h': 987214377.6822529,
#     'volume_change_24h': -30.3838,
#     'percent_change_1h': -0.06208121,
#     'percent_change_24h': -0.73345404,
#     'percent_change_7d': 30.92150446,
#     'percent_change_30d': 92.48886055,
#     'percent_change_60d': 95.4567592,
#     'percent_change_90d': 112.79473333,
#     'market_cap': 2747911379.8077693,
#     'market_cap_dominance': 0.0994,
#     'fully_diluted_market_cap': 3293512485.93,
#     'market_cap_by_total_supply': 3293512485.93353,
#     'last_updated': '2021-11-07T15:28:03.000Z'}}),
#  (2280,
#   'Filecoin',
#   'FIL',
#   {'USD': {'price': 61.89747956185272,
#     'volume_24h': 467247890.21422005,
#     'volume_change_24h': -41.7198,
#     'percent_change_1h': -0.09385487,
#     'percent_change_24h': 1.79634133,
#     'percent_change_7d': -2.80972059,
#     'percent_change_30d': -19.88333041,
#     'percent_change_60d': -27.51850118,
#     'percent_change_90d': -8.70202827,
#     'market_cap': 7472220033.086289,
#     'market_cap_dominance': 0.2704,
#     'fully_diluted_market_cap': 7472220033.09,
#     'market_cap_by_total_supply': 7472220033.086289,
#     'last_updated': '2021-11-07T15:28:04.000Z'}}),
#  (3180,
#   'Compound Coin',
#   'COMP',
#   {'USD': {'price': 8.466361e-08,
#     'volume_24h': 170.21443842,
#     'volume_change_24h': -89.1643,
#     'percent_change_1h': -0.34551302,
#     'percent_change_24h': -6.02250266,
#     'percent_change_7d': -9.56475807,
#     'percent_change_30d': -25.52186509,
#     'percent_change_60d': -63.90979247,
#     'percent_change_90d': -74.61401787,
#     'market_cap': 4549.121203026612,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 4595.69,
#     'market_cap_by_total_supply': 4595.687035247376,
#     'last_updated': '2021-11-07T15:28:03.000Z'}}),
#  (3794,
#   'Cosmos',
#   'ATOM',
#   {'USD': {'price': 35.8116188564261,
#     'volume_24h': 332224440.51572114,
#     'volume_change_24h': -27.5961,
#     'percent_change_1h': -0.13966908,
#     'percent_change_24h': 1.09472145,
#     'percent_change_7d': -2.07498914,
#     'percent_change_30d': -1.52902482,
#     'percent_change_60d': 74.71534611,
#     'percent_change_90d': 157.70733495,
#     'market_cap': 8027940798.565071,
#     'market_cap_dominance': 0.2905,
#     'fully_diluted_market_cap': 10097300976.97,
#     'market_cap_by_total_supply': 10097300976.970966,
#     'last_updated': '2021-11-07T15:28:08.000Z'}}),
#  (3890,
#   'Polygon',
#   'MATIC',
#   {'USD': {'price': 1.9056924113017,
#     'volume_24h': 657963771.9226898,
#     'volume_change_24h': -14.4748,
#     'percent_change_1h': 0.03530846,
#     'percent_change_24h': 2.62334783,
#     'percent_change_7d': 3.36148175,
#     'percent_change_30d': 37.35053825,
#     'percent_change_60d': 46.41919085,
#     'percent_change_90d': 67.13076757,
#     'market_cap': 13001230034.006084,
#     'market_cap_dominance': 0.4705,
#     'fully_diluted_market_cap': 19056924113.02,
#     'market_cap_by_total_supply': 19056924113.017,
#     'last_updated': '2021-11-07T15:27:09.000Z'}}),
#  (4030,
#   'Algorand',
#   'ALGO',
#   {'USD': {'price': 1.85137030466614,
#     'volume_24h': 176561970.5450802,
#     'volume_change_24h': -20.4879,
#     'percent_change_1h': 0.20837962,
#     'percent_change_24h': 1.6638817,
#     'percent_change_7d': 2.62774514,
#     'percent_change_30d': -6.94189439,
#     'percent_change_60d': 7.36563524,
#     'percent_change_90d': 114.81968058,
#     'market_cap': 11535298249.412134,
#     'market_cap_dominance': 0.4174,
#     'fully_diluted_market_cap': 18513703046.66,
#     'market_cap_by_total_supply': 12389112687.953577,
#     'last_updated': '2021-11-07T15:28:08.000Z'}}),
#  (4307,
#   'UNICORN Token',
#   'UNI',
#   {'USD': {'price': 0.00012367528985,
#     'volume_24h': 9.71469402,
#     'volume_change_24h': 1.7363,
#     'percent_change_1h': -0.34177113,
#     'percent_change_24h': 1.73627322,
#     'percent_change_7d': -59.27179347,
#     'percent_change_30d': -54.68402464,
#     'percent_change_60d': -32.96644076,
#     'percent_change_90d': 34.58070351,
#     'market_cap': 13222.435479059543,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 1212017.84,
#     'market_cap_by_total_supply': 1212017.84053,
#     'last_updated': '2021-11-07T15:28:04.000Z'}}),
#  (5426,
#   'Solana',
#   'SOL',
#   {'USD': {'price': 252.24633479247626,
#     'volume_24h': 3291852096.6735134,
#     'volume_change_24h': 3.4074,
#     'percent_change_1h': -0.0148386,
#     'percent_change_24h': 1.02490516,
#     'percent_change_7d': 27.20739175,
#     'percent_change_30d': 51.08777244,
#     'percent_change_60d': 55.67833882,
#     'percent_change_90d': 534.2498653,
#     'market_cap': 76307722031.62643,
#     'market_cap_dominance': 2.7615,
#     'fully_diluted_market_cap': 128237937339.53,
#     'market_cap_by_total_supply': 128237937339.53098,
#     'last_updated': '2021-11-07T15:28:05.000Z'}}),
#  (5692,
#   'Compound',
#   'COMP',
#   {'USD': {'price': 360.6041981030181,
#     'volume_24h': 109490434.82304932,
#     'volume_change_24h': -18.43,
#     'percent_change_1h': -0.77026458,
#     'percent_change_24h': 4.74645377,
#     'percent_change_7d': 6.67943823,
#     'percent_change_30d': 8.64355474,
#     'percent_change_60d': -11.47683931,
#     'percent_change_90d': -25.57456656,
#     'market_cap': 2170438898.4377985,
#     'market_cap_dominance': 0.0785,
#     'fully_diluted_market_cap': 3606041981.03,
#     'market_cap_by_total_supply': 3606041981.0301814,
#     'last_updated': '2021-11-07T15:28:07.000Z'}}),
#  (5711,
#   'Golden Ratio Token',
#   'GRT',
#   {'USD': {'price': 1.06520507595911,
#     'volume_24h': 1661904.6878614,
#     'volume_change_24h': -47.376,
#     'percent_change_1h': 0.221093,
#     'percent_change_24h': 3.22414323,
#     'percent_change_7d': 16.17333081,
#     'percent_change_30d': 46.18072265,
#     'percent_change_60d': 32.02236538,
#     'percent_change_90d': 50.62234762,
#     'market_cap': 0,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 17235.02,
#     'market_cap_by_total_supply': 17235.0181290184,
#     'last_updated': '2021-11-07T15:28:07.000Z'}}),
#  (5864,
#   'yearn.finance',
#   'YFI',
#   {'USD': {'price': 34249.03811344374,
#     'volume_24h': 111208968.94982041,
#     'volume_change_24h': -1.3423,
#     'percent_change_1h': -0.39561172,
#     'percent_change_24h': 4.0303183,
#     'percent_change_7d': 1.73197757,
#     'percent_change_30d': -5.26908882,
#     'percent_change_60d': -1.47559,
#     'percent_change_90d': 1.0078872,
#     'market_cap': 1254806710.6548908,
#     'market_cap_dominance': 0.0454,
#     'fully_diluted_market_cap': 1255775231.47,
#     'market_cap_by_total_supply': 1255775231.467528,
#     'last_updated': '2021-11-07T15:28:08.000Z'}}),
#  (6538,
#   'Curve DAO Token',
#   'CRV',
#   {'USD': {'price': 4.36173042350267,
#     'volume_24h': 278195315.82953036,
#     'volume_change_24h': -4.3355,
#     'percent_change_1h': 1.46528708,
#     'percent_change_24h': 8.95180404,
#     'percent_change_7d': -1.86957612,
#     'percent_change_30d': 54.22430817,
#     'percent_change_60d': 123.29631175,
#     'percent_change_90d': 132.05013434,
#     'market_cap': 1803520062.6289904,
#     'market_cap_dominance': 0.0653,
#     'fully_diluted_market_cap': 14406927744.9,
#     'market_cap_by_total_supply': 7060581505.954194,
#     'last_updated': '2021-11-07T15:28:05.000Z'}}),
#  (6636,
#   'Polkadot',
#   'DOT',
#   {'USD': {'price': 53.06767502840045,
#     'volume_24h': 1548802337.8312247,
#     'volume_change_24h': -12.2066,
#     'percent_change_1h': -0.66698318,
#     'percent_change_24h': 4.73129273,
#     'percent_change_7d': 25.61895915,
#     'percent_change_30d': 56.76053359,
#     'percent_change_60d': 89.30892413,
#     'percent_change_90d': 155.09210318,
#     'market_cap': 52408538150.912926,
#     'market_cap_dominance': 1.8957,
#     'fully_diluted_market_cap': 58549750077.02,
#     'market_cap_by_total_supply': 58549750077.02058,
#     'last_updated': '2021-11-07T15:28:06.000Z'}}),
#  (6719,
#   'The Graph',
#   'GRT',
#   {'USD': {'price': 1.06387277375895,
#     'volume_24h': 158835660.1217478,
#     'volume_change_24h': -36.7535,
#     'percent_change_1h': 0.09938425,
#     'percent_change_24h': 2.9257521,
#     'percent_change_7d': 15.01266501,
#     'percent_change_30d': 45.91347925,
#     'percent_change_60d': 31.81811882,
#     'percent_change_90d': 50.10333387,
#     'market_cap': 5016942287.536716,
#     'market_cap_dominance': 0.1816,
#     'fully_diluted_market_cap': 10699415754.63,
#     'market_cap_by_total_supply': 10638727737.5895,
#     'last_updated': '2021-11-07T15:28:07.000Z'}}),
#  (7083,
#   'Uniswap',
#   'UNI',
#   {'USD': {'price': 25.18920908269433,
#     'volume_24h': 173213365.68081266,
#     'volume_change_24h': -33.7431,
#     'percent_change_1h': -0.64655852,
#     'percent_change_24h': 1.10196341,
#     'percent_change_7d': 2.6413126,
#     'percent_change_30d': -2.42174226,
#     'percent_change_60d': 8.39331714,
#     'percent_change_90d': -10.86479358,
#     'market_cap': 15808649094.064651,
#     'market_cap_dominance': 0.5718,
#     'fully_diluted_market_cap': 25189209082.69,
#     'market_cap_by_total_supply': 25189209082.69433,
#     'last_updated': '2021-11-07T15:27:21.000Z'}}),
#  (7278,
#   'Aave',
#   'AAVE',
#   {'USD': {'price': 321.4572935384642,
#     'volume_24h': 203176558.822497,
#     'volume_change_24h': -28.3634,
#     'percent_change_1h': -0.14707462,
#     'percent_change_24h': 2.35927452,
#     'percent_change_7d': 3.95655872,
#     'percent_change_30d': 0.3008365,
#     'percent_change_60d': -4.3273747,
#     'percent_change_90d': -15.31225915,
#     'market_cap': 4257207875.1517262,
#     'market_cap_dominance': 0.154,
#     'fully_diluted_market_cap': 5143316696.62,
#     'market_cap_by_total_supply': 5143316696.615428,
#     'last_updated': '2021-11-07T15:28:03.000Z'}}),
#  (8104,
#   '1inch Network',
#   '1INCH',
#   {'USD': {'price': 4.55702502755284,
#     'volume_24h': 162352221.5140035,
#     'volume_change_24h': 2.272,
#     'percent_change_1h': 0.2228994,
#     'percent_change_24h': 5.51696851,
#     'percent_change_7d': 1.913526,
#     'percent_change_30d': 40.99621648,
#     'percent_change_60d': 57.96385305,
#     'percent_change_90d': 70.01750505,
#     'market_cap': 821914705.4863534,
#     'market_cap_dominance': 0.0297,
#     'fully_diluted_market_cap': 6835537541.33,
#     'market_cap_by_total_supply': 6835537541.329261,
#     'last_updated': '2021-11-07T15:27:21.000Z'}}),
#  (12003,
#   'SOL RUNE - Rune.Game',
#   'SOL',
#   {'USD': {'price': 1.27502381897576,
#     'volume_24h': 1242.4142615,
#     'volume_change_24h': 80.9086,
#     'percent_change_1h': -0.87634215,
#     'percent_change_24h': -2.860976,
#     'percent_change_7d': 27.32476126,
#     'percent_change_30d': 32.41233109,
#     'percent_change_60d': 17.66580704,
#     'percent_change_90d': 17.66580704,
#     'market_cap': 0,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 151539.13,
#     'market_cap_by_total_supply': 0,
#     'last_updated': '2021-11-07T15:27:12.000Z'}}),
#  (12712,
#   'Genesis Mana',
#   'MANA',
#   {'USD': {'price': 1212.2360775481925,
#     'volume_24h': 10382.47958223,
#     'volume_change_24h': -34.9741,
#     'percent_change_1h': -1.2680514,
#     'percent_change_24h': 0.57964011,
#     'percent_change_7d': 2.21677718,
#     'percent_change_30d': -26.70660743,
#     'percent_change_60d': -26.70660743,
#     'percent_change_90d': -26.70660743,
#     'market_cap': 0,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 499441.26,
#     'market_cap_by_total_supply': 499441.2639498553,
#     'last_updated': '2021-11-07T15:28:06.000Z'}})]

# %% [markdown]
# Extract market cap data and store in temp lists

# %%
market_caps = [temp[i][3]["USD"]["market_cap"] for i in range(len(temp))]
market_cap_dominances = [temp[i][3]["USD"]["market_cap_dominance"] for i in range(len(temp))]
market_caps
# Out:
# [1166282842399.5542,
#  13761623386.007582,
#  57011237096.0785,
#  34971437132.85317,
#  2010621126.8396711,
#  8774644306.580523,
#  542390676446.66644,
#  7026421414.476563,
#  3205457070.8473043,
#  2098822300.6313105,
#  2924573588.2783346,
#  1485193112.557301,
#  3745290709.01238,
#  4308977701.839139,
#  11243503223.36315,
#  110029505013.77098,
#  7435504664.020182,
#  5177320223.807516,
#  14907439403.85547,
#  67030627627.43331,
#  5498645614.734127,
#  2747911379.8077693,
#  7472220033.086289,
#  4549.121203026612,
#  8027940798.565071,
#  13001230034.006084,
#  11535298249.412134,
#  13222.435479059543,
#  76307722031.62643,
#  2170438898.4377985,
#  0,
#  1254806710.6548908,
#  1803520062.6289904,
#  52408538150.912926,
#  5016942287.536716,
#  15808649094.064651,
#  4257207875.1517262,
#  821914705.4863534,
#  0,
#  0]

# %% [markdown]
# ## Store these all in a Pandas Table

# %% [markdown]
# Add these two lists to existing dataframe:merged_df

# %%
merged_df["Market Cap"] = market_caps
merged_df["Market Cap Share"] = market_cap_dominances
merged_df.head()
# Out:
#     id Symbol      Name    Market Cap  Market Cap Share  \
# 0    1    BTC   Bitcoin  1.166283e+12           42.2040
# 1    2    LTC  Litecoin  1.376162e+10            0.4978
# 2   52    XRP       XRP  5.701124e+10            2.0632
# 3   74   DOGE  Dogecoin  3.497144e+10            1.2656
# 4  131   DASH      Dash  2.010621e+09            0.0728
#
#    Market Cap Share-Modified
# 0                   2.501947
# 1                   1.210857
# 2                   5.018561
# 3                   3.078466
# 4                   0.177080

# %%
merged_df.sort_values(by="Market Cap")
# Out:
#        id Symbol                   Name    Market Cap  Market Cap Share  \
# 39   8104  1INCH          1inch Network  0.000000e+00            0.0000
# 30   7083    UNI                Uniswap  0.000000e+00            0.0000
# 38   7278   AAVE                   Aave  0.000000e+00            0.0000
# 23   2280    FIL               Filecoin  4.549121e+03            0.0000
# 27   3890  MATIC                Polygon  1.322244e+04            0.0000
# 37   6636    DOT               Polkadot  8.219147e+08            0.0297
# 31   5426    SOL                 Solana  1.254807e+09            0.0454
# 11   1697    BAT  Basic Attention Token  1.485193e+09            0.0537
# 32  12003    SOL   SOL RUNE - Rune.Game  1.803520e+09            0.0653
# 4     131   DASH                   Dash  2.010621e+09            0.0728
# 9    1437    ZEC                  Zcash  2.098822e+09            0.0759
# 29   4307    UNI          UNICORN Token  2.170439e+09            0.0785
# 21   2011    XTZ                  Tezos  2.747911e+09            0.0994
# 10   1518    MKR                  Maker  2.924574e+09            0.1058
# 8    1376    NEO                    Neo  3.205457e+09            0.1160
# 12   1720  MIOTA                   IOTA  3.745291e+09            0.1355
# 36   6538    CRV        Curve DAO Token  4.257208e+09            0.1540
# 13   1765    EOS                    EOS  4.308978e+09            0.1559
# 34   6719    GRT              The Graph  5.016942e+09            0.1816
# 17   1966   MANA           Decentraland  5.177320e+09            0.1874
# 20   2010    ADA                Cardano  5.498646e+09            0.1990
# 7    1321    ETC       Ethereum Classic  7.026421e+09            0.2543
# 16   1958    TRX                   TRON  7.435505e+09            0.2691
# 22   2130    ENJ             Enjin Coin  7.472220e+09            0.2704
# 24   3180   COMP          Compound Coin  8.027941e+09            0.2905
# 5     512    XLM                Stellar  8.774644e+09            0.3175
# 14   1831    BCH           Bitcoin Cash  1.124350e+10            0.4069
# 26   3794   ATOM                 Cosmos  1.153530e+10            0.4174
# 25   5692   COMP               Compound  1.300123e+10            0.4705
# 1       2    LTC               Litecoin  1.376162e+10            0.4978
# 18  12712   MANA           Genesis Mana  1.490744e+10            0.5395
# 35   5864    YFI          yearn.finance  1.580865e+10            0.5718
# 3      74   DOGE               Dogecoin  3.497144e+10            1.2656
# 33   5711    GRT     Golden Ratio Token  5.240854e+10            1.8957
# 2      52    XRP                    XRP  5.701124e+10            2.0632
# 19   1975   LINK              Chainlink  6.703063e+10            2.4258
# 28   4030   ALGO               Algorand  7.630772e+10            2.7615
# 15   1839    BNB           Binance Coin  1.100295e+11            3.9817
# 6    1027    ETH               Ethereum  5.423907e+11           19.6277
# 0       1    BTC                Bitcoin  1.166283e+12           42.2040
#
#     Market Cap Share-Modified
# 39                   0.000000
# 30                   0.000000
# 38                   0.000000
# 23                   0.000000
# 27                   0.000000
# 37                   0.072243
# 31                   0.110432
# 11                   0.130621
# 32                   0.158837
# 4                    0.177080
# 9                    0.184620
# 29                   0.190945
# 21                   0.241782
# 10                   0.257350
# 8                    0.282160
# 12                   0.329592
# 36                   0.374592
# 13                   0.379214
# 34                   0.441727
# 17                   0.455835
# 20                   0.484051
# 7                    0.618563
# 16                   0.654563
# 22                   0.657725
# 24                   0.706617
# 5                    0.772292
# 14                   0.989750
# 26                   1.015291
# 25                   1.144452
# 1                    1.210857
# 18                   1.312289
# 35                   1.390856
# 3                    3.078466
# 33                   4.611131
# 2                    5.018561
# 19                   5.900555
# 28                   6.717117
# 15                   9.685152
# 6                   47.742736
# 0                    2.501947

# %% [markdown]
# Convert to billions

# %%
#merged_df["Market Cap"] = merged_df["Market Cap"]/10**9
merged_df.head()
# Out:
#     id Symbol      Name   Market Cap  Market Cap Share
# 0    1    BTC   Bitcoin  1166.282842           42.2040
# 1    2    LTC  Litecoin    13.761623            0.4978
# 2   52    XRP       XRP    57.011237            2.0632
# 3   74   DOGE  Dogecoin    34.971437            1.2656
# 4  131   DASH      Dash     2.010621            0.0728

# %% [markdown]
# ## Save the dataframe

# %%
merged_df.to_csv("CoinMarketCaps07.11.21.csv")

# %% [markdown]
# # Calculations for Equal weight portfolio

# %%
merged_df["Market Cap Share"].sum()
# Out:
# 82.2868

# %%
merged_df["Market Cap Share"] = merged_df["Market Cap Share"]/82.2868*100
merged_df.head()
# Out:
#     id Symbol      Name   Market Cap  Market Cap Share  \
# 0    1    BTC   Bitcoin  1166.282842         51.288907
# 1    2    LTC  Litecoin    13.761623          0.604957
# 2   52    XRP       XRP    57.011237          2.507328
# 3   74   DOGE  Dogecoin    34.971437          1.538035
# 4  131   DASH      Dash     2.010621          0.088471
#
#    Market Cap Share-Modified
# 0                   1.600000
# 1                  14.197743
# 2                  58.844482
# 3                  36.096150
# 4                   2.076327

# %%
merged_df["Market Cap Share-Modified"] = merged_df["Market Cap Share"]
merged_df.head()
# Out:
#     id Symbol      Name   Market Cap  Market Cap Share  \
# 0    1    BTC   Bitcoin  1166.282842         51.288907
# 1    2    LTC  Litecoin    13.761623          0.604957
# 2   52    XRP       XRP    57.011237          2.507328
# 3   74   DOGE  Dogecoin    34.971437          1.538035
# 4  131   DASH      Dash     2.010621          0.088471
#
#    Market Cap Share-Modified
# 0                  51.288907
# 1                   0.604957
# 2                   2.507328
# 3                   1.538035
# 4                   0.088471

# %% [markdown]
# ### Limit Bitcoin exposure and recalculate

# %%
merged_df.iloc[0,5] = 1.25
merged_df.head(1)
# Out:
#    id Symbol     Name   Market Cap  Market Cap Share  \
# 0   1    BTC  Bitcoin  1166.282842         51.288907
#
#    Market Cap Share-Modified
# 0                       1.25

# %%
merged_df["Market Cap Share-Modified"].sum()
# Out:
# 49.96109339529548

# %%
merged_df.iloc[:,5] = merged_df.iloc[:,5] / merged_df["Market Cap Share-Modified"].sum() * 100
merged_df[(merged_df["Market Cap Share-Modified"] > 2)]
# Out:
#       id Symbol                Name   Market Cap  Market Cap Share  \
# 0      1    BTC             Bitcoin  1166.282842         51.288907
# 2     52    XRP                 XRP    57.011237          2.507328
# 3     74   DOGE            Dogecoin    34.971437          1.538035
# 6   1027    ETH            Ethereum   542.390676         23.852793
# 15  1839    BNB        Binance Coin   110.029505          4.838808
# 19  1975   LINK           Chainlink    67.030628          2.947982
# 28  4030   ALGO            Algorand    76.307722          3.355945
# 33  5711    GRT  Golden Ratio Token    52.408538          2.303772
#
#     Market Cap Share-Modified
# 0                    2.501947
# 2                    5.018561
# 3                    3.078466
# 6                   47.742736
# 15                   9.685152
# 19                   5.900555
# 28                   6.717117
# 33                   4.611131

# %% [markdown]
# ## Check which coins, without manipulating bitcoin, would reach threshold

# %%
merged_df[(merged_df["Market Cap Share"] > 2)]
# Out:
#       id Symbol                Name   Market Cap  Market Cap Share  \
# 0      1    BTC             Bitcoin  1166.282842         51.288907
# 2     52    XRP                 XRP    57.011237          2.507328
# 6   1027    ETH            Ethereum   542.390676         23.852793
# 15  1839    BNB        Binance Coin   110.029505          4.838808
# 19  1975   LINK           Chainlink    67.030628          2.947982
# 28  4030   ALGO            Algorand    76.307722          3.355945
# 33  5711    GRT  Golden Ratio Token    52.408538          2.303772
#
#     Market Cap Share-Modified
# 0                    2.501947
# 2                    5.018561
# 6                   47.742736
# 15                   9.685152
# 19                   5.900555
# 28                   6.717117
# 33                   4.611131

# %% [markdown]
# For a 1000USD Portfolio with minimum purchase size of 25$, minimum share is 2.5%

# %%
larger_coins = merged_df[(merged_df["Market Cap Share-Modified"] > 1)]
larger_coins
# Out:
#        id Symbol                Name   Market Cap  Market Cap Share  \
# 0       1    BTC             Bitcoin  1166.282842         51.288907
# 2      52    XRP                 XRP    57.011237          2.507328
# 3      74   DOGE            Dogecoin    34.971437          1.538035
# 6    1027    ETH            Ethereum   542.390676         23.852793
# 15   1839    BNB        Binance Coin   110.029505          4.838808
# 18  12712   MANA        Genesis Mana    14.907439          0.655634
# 19   1975   LINK           Chainlink    67.030628          2.947982
# 28   4030   ALGO            Algorand    76.307722          3.355945
# 33   5711    GRT  Golden Ratio Token    52.408538          2.303772
# 35   5864    YFI       yearn.finance    15.808649          0.694887
#
#     Market Cap Share-Modified
# 0                   15.695854
# 2                    3.935465
# 3                    2.414078
# 6                   37.438995
# 15                   7.594922
# 18                   1.029073
# 19                   4.627109
# 28                   5.267443
# 33                   3.615966
# 35                   1.090684

# %%
larger_coins["Market Cap Share-Modified"].sum()
# Out:
# 82.7095885195501

# %% [markdown]
# ## Sort original list for reference

# %%
merged_df.sort_values(by="Market Cap",ascending=False)
# Out:
#        id Symbol                   Name   Market Cap  Market Cap Share  \
# 0       1    BTC                Bitcoin  1166.282842         51.288907
# 6    1027    ETH               Ethereum   542.390676         23.852793
# 15   1839    BNB           Binance Coin   110.029505          4.838808
# 28   4030   ALGO               Algorand    76.307722          3.355945
# 19   1975   LINK              Chainlink    67.030628          2.947982
# 2      52    XRP                    XRP    57.011237          2.507328
# 33   5711    GRT     Golden Ratio Token    52.408538          2.303772
# 3      74   DOGE               Dogecoin    34.971437          1.538035
# 35   5864    YFI          yearn.finance    15.808649          0.694887
# 18  12712   MANA           Genesis Mana    14.907439          0.655634
# 1       2    LTC               Litecoin    13.761623          0.604957
# 25   5692   COMP               Compound    13.001230          0.571781
# 26   3794   ATOM                 Cosmos    11.535298          0.507250
# 14   1831    BCH           Bitcoin Cash    11.243503          0.494490
# 5     512    XLM                Stellar     8.774644          0.385846
# 24   3180   COMP          Compound Coin     8.027941          0.353034
# 22   2130    ENJ             Enjin Coin     7.472220          0.328607
# 16   1958    TRX                   TRON     7.435505          0.327027
# 7    1321    ETC       Ethereum Classic     7.026421          0.309041
# 20   2010    ADA                Cardano     5.498646          0.241837
# 17   1966   MANA           Decentraland     5.177320          0.227740
# 34   6719    GRT              The Graph     5.016942          0.220692
# 13   1765    EOS                    EOS     4.308978          0.189459
# 36   6538    CRV        Curve DAO Token     4.257208          0.187150
# 12   1720  MIOTA                   IOTA     3.745291          0.164668
# 8    1376    NEO                    Neo     3.205457          0.140970
# 10   1518    MKR                  Maker     2.924574          0.128575
# 21   2011    XTZ                  Tezos     2.747911          0.120797
# 29   4307    UNI          UNICORN Token     2.170439          0.095398
# 9    1437    ZEC                  Zcash     2.098822          0.092238
# 4     131   DASH                   Dash     2.010621          0.088471
# 32  12003    SOL   SOL RUNE - Rune.Game     1.803520          0.079357
# 11   1697    BAT  Basic Attention Token     1.485193          0.065260
# 31   5426    SOL                 Solana     1.254807          0.055173
# 37   6636    DOT               Polkadot     0.821915          0.036093
# 27   3890  MATIC                Polygon     0.000013          0.000000
# 23   2280    FIL               Filecoin     0.000005          0.000000
# 38   7278   AAVE                   Aave     0.000000          0.000000
# 30   7083    UNI                Uniswap     0.000000          0.000000
# 39   8104  1INCH          1inch Network     0.000000          0.000000
#
#     Market Cap Share-Modified
# 0                    2.501947
# 6                   47.742736
# 15                   9.685152
# 28                   6.717117
# 19                   5.900555
# 2                    5.018561
# 33                   4.611131
# 3                    3.078466
# 35                   1.390856
# 18                   1.312289
# 1                    1.210857
# 25                   1.144452
# 26                   1.015291
# 14                   0.989750
# 5                    0.772292
# 24                   0.706617
# 22                   0.657725
# 16                   0.654563
# 7                    0.618563
# 20                   0.484051
# 17                   0.455835
# 34                   0.441727
# 13                   0.379214
# 36                   0.374592
# 12                   0.329592
# 8                    0.282160
# 10                   0.257350
# 21                   0.241782
# 29                   0.190945
# 9                    0.184620
# 4                    0.177080
# 32                   0.158837
# 11                   0.130621
# 31                   0.110432
# 37                   0.072243
# 27                   0.000000
# 23                   0.000000
# 38                   0.000000
# 30                   0.000000
# 39                   0.000000

# %% [markdown]
# # Define a function to easily let you manipulate market cap share

# %% [markdown]
# ## TODO:
# There is an error associated with the market caps of some coins, which falsely appear to be zero- fix these
# Then write a funciton to customize your portfolio by setting max exposure rules

# %%
def portfolio_customizer(table,)
